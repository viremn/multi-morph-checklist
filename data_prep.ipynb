# %% [markdown]
# # Loading Data

# %%
import glob

langs = ['en', 'de', 'fi', 'ja']

tasks = ['negation1', 'negation2', 
         'numerals1', 'numerals2', 
         'spatial1', 'spatial2', 
         'temporal1', 'temporal2', 
         'comparative1', 'comparative2',
         'counters']

files = [{'task': task, 'lang': lang, 'path': file} for lang in langs for task in tasks for file in glob.glob(f'/home/norrman/GitHub/multi-morph-checklist/export/*{task}*/{lang}.txt')]
for file in files:
    if '_fam/' in file['path']:
        file['polite'] = 'fam'
    elif '_norm/' in file['path']:
        file['polite'] = 'norm'
    elif '_form/' in file['path']:
        file['polite'] = 'form'
    else:
        file['polite'] = ''

files
# Out:
# [{'task': 'negation1',
#   'lang': 'en',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/negation1/en.txt',
#   'polite': ''},
#  {'task': 'negation2',
#   'lang': 'en',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/negation2/en.txt',
#   'polite': ''},
#  {'task': 'numerals1',
#   'lang': 'en',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/numerals1/en.txt',
#   'polite': ''},
#  {'task': 'numerals2',
#   'lang': 'en',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/numerals2/en.txt',
#   'polite': ''},
#  {'task': 'spatial1',
#   'lang': 'en',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/spatial1/en.txt',
#   'polite': ''},
#  {'task': 'spatial2',
#   'lang': 'en',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/spatial2/en.txt',
#   'polite': ''},
#  {'task': 'temporal1',
#   'lang': 'en',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/temporal1/en.txt',
#   'polite': ''},
#  {'task': 'temporal2',
#   'lang': 'en',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/temporal2/en.txt',
#   'polite': ''},
#  {'task': 'comparative1',
#   'lang': 'en',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/comparative1/en.txt',
#   'polite': ''},
#  {'task': 'comparative2',
#   'lang': 'en',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/comparative2/en.txt',
#   'polite': ''},
#  {'task': 'negation1',
#   'lang': 'de',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/negation1/de.txt',
#   'polite': ''},
#  {'task': 'negation2',
#   'lang': 'de',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/negation2/de.txt',
#   'polite': ''},
#  {'task': 'numerals1',
#   'lang': 'de',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/numerals1/de.txt',
#   'polite': ''},
#  {'task': 'numerals2',
#   'lang': 'de',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/numerals2/de.txt',
#   'polite': ''},
#  {'task': 'spatial1',
#   'lang': 'de',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/spatial1/de.txt',
#   'polite': ''},
#  {'task': 'spatial2',
#   'lang': 'de',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/spatial2/de.txt',
#   'polite': ''},
#  {'task': 'temporal1',
#   'lang': 'de',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/temporal1/de.txt',
#   'polite': ''},
#  {'task': 'temporal2',
#   'lang': 'de',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/temporal2/de.txt',
#   'polite': ''},
#  {'task': 'comparative1',
#   'lang': 'de',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/comparative1/de.txt',
#   'polite': ''},
#  {'task': 'comparative2',
#   'lang': 'de',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/comparative2/de.txt',
#   'polite': ''},
#  {'task': 'negation1',
#   'lang': 'fi',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/negation1/fi.txt',
#   'polite': ''},
#  {'task': 'negation2',
#   'lang': 'fi',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/negation2/fi.txt',
#   'polite': ''},
#  {'task': 'numerals1',
#   'lang': 'fi',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/numerals1/fi.txt',
#   'polite': ''},
#  {'task': 'numerals2',
#   'lang': 'fi',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/numerals2/fi.txt',
#   'polite': ''},
#  {'task': 'spatial1',
#   'lang': 'fi',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/spatial1/fi.txt',
#   'polite': ''},
#  {'task': 'spatial2',
#   'lang': 'fi',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/spatial2/fi.txt',
#   'polite': ''},
#  {'task': 'temporal1',
#   'lang': 'fi',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/temporal1/fi.txt',
#   'polite': ''},
#  {'task': 'temporal2',
#   'lang': 'fi',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/temporal2/fi.txt',
#   'polite': ''},
#  {'task': 'comparative1',
#   'lang': 'fi',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/comparative1/fi.txt',
#   'polite': ''},
#  {'task': 'comparative2',
#   'lang': 'fi',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/comparative2/fi.txt',
#   'polite': ''},
#  {'task': 'negation1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/negation1_fam/ja.txt',
#   'polite': 'fam'},
#  {'task': 'negation1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/negation1_norm/ja.txt',
#   'polite': 'norm'},
#  {'task': 'negation1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/negation1_form/ja.txt',
#   'polite': 'form'},
#  {'task': 'negation2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/negation2_norm/ja.txt',
#   'polite': 'norm'},
#  {'task': 'negation2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/negation2_fam/ja.txt',
#   'polite': 'fam'},
#  {'task': 'negation2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/negation2_form/ja.txt',
#   'polite': 'form'},
#  {'task': 'numerals1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/numerals1_norm/ja.txt',
#   'polite': 'norm'},
#  {'task': 'numerals1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/numerals1_form/ja.txt',
#   'polite': 'form'},
#  {'task': 'numerals1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/numerals1_fam/ja.txt',
#   'polite': 'fam'},
#  {'task': 'numerals2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/numerals2_fam/ja.txt',
#   'polite': 'fam'},
#  {'task': 'numerals2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/numerals2_form/ja.txt',
#   'polite': 'form'},
#  {'task': 'numerals2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/numerals2_norm/ja.txt',
#   'polite': 'norm'},
#  {'task': 'spatial1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/spatial1_form/ja.txt',
#   'polite': 'form'},
#  {'task': 'spatial1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/spatial1_fam/ja.txt',
#   'polite': 'fam'},
#  {'task': 'spatial1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/spatial1_norm/ja.txt',
#   'polite': 'norm'},
#  {'task': 'spatial2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/spatial2_fam/ja.txt',
#   'polite': 'fam'},
#  {'task': 'spatial2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/spatial2_form/ja.txt',
#   'polite': 'form'},
#  {'task': 'spatial2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/spatial2_norm/ja.txt',
#   'polite': 'norm'},
#  {'task': 'temporal1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/temporal1_norm/ja.txt',
#   'polite': 'norm'},
#  {'task': 'temporal1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/temporal1_form/ja.txt',
#   'polite': 'form'},
#  {'task': 'temporal1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/temporal1_fam/ja.txt',
#   'polite': 'fam'},
#  {'task': 'temporal2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/temporal2_form/ja.txt',
#   'polite': 'form'},
#  {'task': 'temporal2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/temporal2_norm/ja.txt',
#   'polite': 'norm'},
#  {'task': 'temporal2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/temporal2_fam/ja.txt',
#   'polite': 'fam'},
#  {'task': 'comparative1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/comparative1_form/ja.txt',
#   'polite': 'form'},
#  {'task': 'comparative1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/comparative1_fam/ja.txt',
#   'polite': 'fam'},
#  {'task': 'comparative1',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/comparative1_norm/ja.txt',
#   'polite': 'norm'},
#  {'task': 'comparative2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/comparative2_norm/ja.txt',
#   'polite': 'norm'},
#  {'task': 'comparative2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/comparative2_fam/ja.txt',
#   'polite': 'fam'},
#  {'task': 'comparative2',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/comparative2_form/ja.txt',
#   'polite': 'form'},
#  {'task': 'counters',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/zh_ja_counters_fam/ja.txt',
#   'polite': 'fam'},
#  {'task': 'counters',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/zh_ja_counters_form/ja.txt',
#   'polite': 'form'},
#  {'task': 'counters',
#   'lang': 'ja',
#   'path': '/home/norrman/GitHub/multi-morph-checklist/export/zh_ja_counters_norm/ja.txt',
#   'polite': 'norm'}]

# %%
TARGET_PATTERN = {
    'en': { # {N1} (is/are) {NEG} {P2}, but {P1} is/are.
           'negation1': r".*"
                        r"C\:\s(?:(?P<N1A>\w+)\sand\s(?P<N1B>\w+)|(?P<N1>\w+))\s(?:is|are)\snot\s((?:a|an)\s)?(?P<P2>.+?),\sbut\s(?:(?P<P1A>.+?)\sand\s(?P<P1B>.+?)|(?P<P1>.+?))\s(?:is|are)\."
                        r".*",
                        
            # {N1} (is/are) a {N2}, {P1} are {P2}.
           'negation2': r".*"
                        r"C\:\s(?:(?P<N1A>\w+)\sand\s(?P<N1B>\w+)|(?P<N1>\w+))\s(?:is|are)\s((?:a|an)\s)?(?P<N2>.+?),\s(?:(?P<P1A>.+?)\sand\s(?P<P1B>.+?)|(?P<P1>.+?))\s(?:is|are)\s((?:a|an)\s)?(?P<P2>.+?)\."
                        r".*",
            # C: There are {N1} {N2} and {N3} {N4} {P3}. 
            # Q: How many {P2} in total are {P3}? 
            # A: {P1}.
           'numerals1': r".*"
                        r"C\:\sThere\s(?:is|are)\s(?P<N1A>.+?)\s(?P<N2A>.+?)\sand\s(?P<N1B>.+?)\s(?P<N2B>.+?)\s(?P<P3>.+?)\.\s.*"
                        r"Q\:\sHow\smany\s(?P<P2>.+?)\s.*"
                        r"A:\s(?P<P1>.+?)\."
                        r".*",

            # C: There are {N1A} {P2} and {N1B} {N2} {P3}. Kirk ate {N1C} pineapples. 
            # Q: How many pineapples are on the table? 
            # A: {P1}.
           'numerals2': r".*"
                        r"C\:\sThere\s(?:is|are)\s(?P<N1A>.+?)\s(?P<P2>.+?)\sand\s(?P<N1B>.+?)\s(?P<N2>.+?)\s(?P<P3>.+?)\.\s.*ate\s(?P<N1C>.+?)\s.*"
                        r"A:\s(?P<P1>.+?)\."
                        r".*",

            # C: The {N2} is {N1} and the {P2} are {P1}. 
            # Q: Where are the phones? 
            # A: Next to the shelf.
           'spatial1': r".*"
                       r"C\:\sThe\s(?P<N2>.+?)\s(?:is|are)\s(?P<N1>.+?)\sand\sthe\s(?P<P2>.+?)\s(?:is|are)\s(?P<P1>.+?)\."
                       r".*",
              # C: The {P2} and the {N2} are {P1}. Kirk puts the pens {N1}. 
              # Q: Where is the book? 
              # A: Behind the table.
           'spatial2': r".*"
                       r"C\:\sThe\s(?P<P2>.+?)\sand\sthe\s(?P<N2>.+?)\sare\s(?P<P1>.+?)\.\s\w+\sputs\sthe\s\w+\s(?P<N1>.+?)\."
                       r".*",
               # C: {P1} and {N1} were {N2}, but Lola changed careers and is now a {P2}. 
               # Q: Who is a farmer? 
               # A: Lola.
           'temporal1': r".*"
                        r"C\:\s(?P<P1>.+?)\sand\s(?P<N1>.+?)\swere\s(?P<N2>.+?),\s.*is\snow\san?\s(?P<P2>.+?)\."
                        r".*",
               # C: {P1} and {N1} are {N2}, but Audrey will change careers and will be a {P2}. 
               # Q: Who will be a policeman? 
               # A: Audrey.
           'temporal2': r".*"
                        r"C\:\s(?P<P1>.+?)\sand\s(?P<N1>.+?)\sare\s(?P<N2>.+?),\s.*will\sbe\san?\s(?P<P2>.+?)\.\sQ"
                        r".*",
               # C: {N1} is {N2} than {P1}. 
               # Q: Who is {P2}? 
               # A: Lola.
           'comparative1': r".*"
                           r"C\:\s(?P<N1>.+?)\sis\s(?P<N2>.+?)\sthan\s(?P<P1>.+?)\.\sQ\:\sWho\sis\s(?P<P2>.+?)\?"
                           r".*",
               # C: If the {P1} was more expensive, Lola would {P2} it. If the {N1} was cheaper, Lola would rent it. 
               # Q: What would Lola rent if it was less cheap? 
               # A: The house.
           'comparative2': r".*"
                           r"C\:\sIf\sthe\s(?P<P1>.+?)\swas\s.*would\s(?P<P2>.+?)\sit\.\sIf\sthe\s(?P<N1>.+?)\swas\s"
                           r".*",
           },
    'de': { # {N1} (ist/sind) {NEG} {P2}, aber {P1} ist/sind es.'
           'negation1': r".*"
                        r"C\:\s(?:(?P<N1A>\w+)\sund\s(?P<N1B>\w+)|(?P<N1>\w+))\s(?:ist|sind)\skeine?\s(?P<P2>.+?),\saber\s(?:(?P<P1A>.+?)\sund\s(?P<P1B>.+?)|(?P<P1>.+?))\s(?:ist|sind)\ses\."
                        r".*",

            # {N1} ist/sind ein {N2} und {P1} sind {P2}.
           'negation2': r".*"
                        r"C\:\s(?:(?P<N1A>\w+)\sund\s(?P<N1B>\w+)|(?P<N1>\w+))\s(?:ist|sind)\s(eine?\s)?(?P<N2>.+?)\sund\s(?:(?P<P1A>.+?)\sund\s(?P<P1B>.+?)|(?P<P1>.+?))\s(?:ist|sind)\s(eine?\s)?(?P<P2>.+?)\."
                        r".*",

            # C: Es gibt {N1} {N2} und {N3} {N4} {P3}. 
            # Q: Wie viele {P2} liegen insgesamt {P3}? 
            # A: {P1}.
           'numerals1': r".*"
                        r"C\:\sEs\sgibt\s(?P<N1A>.+?)\s(?P<N2A>.+?)\sund\s(?P<N1B>.+?)\s(?P<N2B>.+?)\s(?P<P3>.+?)\.\s.*"
                        r"Q\:\sWie\sviele\s(?P<P2>.+?)\s.*"
                        r"A:\s(?P<P1>.+?)\."
                        r".*",
            # C: Es gibt {N1A} {P2} und {N1B} {N2} {P3}. Katja aß {N1C} Wassermelone. 
            # Q: Wie viele Wassermelonen gibt es auf dem Tisch? 
            # A: {P1}.
           'numerals2': r".*"
                        r"C\:\sEs\sgibt\s(?P<N1A>.+?)\s(?P<P2>.+?)\sund\s(?P<N1B>.+?)\s(?P<N2>.+?)\s(?P<P3>.+?)\.\s.*aß\s(?P<N1C>.+?)\s.*"
                        r"A:\s(?P<P1>.+?)\."
                        r".*",
            # C: Der {N2} liegt {N1} und die {P2} liegen {P1}. 
            # Q: Wo sind die Bücher? 
            # A: Vor dem Regal.
           'spatial1': r".*"
                       r"C\:\s(?:Der|Die|Das)\s(?P<N2>.+?)\s(?:liegt|liegen)\s(?P<N1>.+?)\sund\s(?:der|die|das)\s(?P<P2>.+?)\s(?:liegt|liegen)\s(?P<P1>.+?)\."
                       r".*",
              # C: Das {P2} und die {N2} liegen {P1}. Judith legt die Papiere {N1}. 
              # Q: Wo ist das Buch? 
              # A: Vor dem Sofa.
           'spatial2': r".*"
                       r"C\:\s(?:Der|Die|Das)\s(?P<P2>.+?)\sund\s(?:der|die|das)\s(?P<N2>.+?)\s(?:liegt|liegen)\s(?P<P1>.+?)\.\s\w+\slegt\s(?:der|die|das|den)\s\w+\s(?P<N1>.+?)\."
                       r".*",
               # C: {P1} und {N1} waren {N2}, aber Klaus hat den Beruf gewechselt und wird {P2}. 
               # Q: Wer ist Manager? 
               # A: Klaus.
           'temporal1': r".*"
                        r"C\:\s(?P<P1>.+?)\sund\s(?P<N1>.+?)\swaren\s(?P<N2>.+?),\s.*und\swird\s(?P<P2>.+?)\."
                        r".*",
               # C: {P1} und {N1} sind {N2}, aber Günter wechselt den Beruf und wird {P2}. 
               # Q: Wer wird Buchhalter? 
               # A: Günter.
           'temporal2': r".*"
                        r"C\:\s(?P<P1>.+?)\sund\s(?P<N1>.+?)\ssind\s(?P<N2>.+?),\s.*und\swird\s(?P<P2>.+?)\."
                        r".*",
               # C: {N1} ist {N2} als {P1}. 
               # Q: Wer ist {P2}? 
               # A: Stefan.
           'comparative1': r".*"
                           r"C\:\s(?P<N1>.+?)\sist\s(?P<N2>.+?)\sals\s(?P<P1>.+?)\.\sQ\:\sWer\sist\s(?P<P2>.+?)\?"
                           r".*",
               # C: Wäre die {P1} älter, würde sie Stefan {P2}. Wäre das {N1} teurer, würde es Stefan mieten. 
               # Q: Was würde Stefan mieten, wäre es weniger neu? 
               # A: Die Wohnung.
           'comparative2': r".*"
                           r"C\:\s\w+\s\w+\s(?P<P1>.+?)\s\w+,\s\w+\s\w+\s\w+\s(?P<P2>.+?)\.\s\w+\s\w+\s(?P<N1>.+?)\s\w+,"
                           r".*",
           },          
    'fi': { # {N1} {NEG} ole {P2} mutta {P1} on/ovat.
           'negation1': r".*"
                        r"C\:\s(?:(?P<N1A>\w+)\sja\s(?P<N1B>\w+)|(?P<N1>\w+))\s(?:ei|eivät)\sole\s(?P<P2>.+?)\smutta\s(?:(?P<P1A>.+?)\sja\s(?P<P1B>.+?)|(?P<P1>.+?))\s(?:on|ovat)\."
                        r".*",

           # {N1} on {N2}, {P1} ovat {P2}. 
           'negation2': r".*"
                        r"C\:\s(?:(?P<N1A>\w+)\sja\s(?P<N1B>\w+)|(?P<N1>\w+))\s(?:on|ovat)\s(?P<N2>.+?),\s(?:(?P<P1A>.+?)\sja\s(?P<P1B>.+?)|(?P<P1>.+?))\s(?:on|ovat)\s(?P<P2>.+?)\."
                        r".*",
              # C: {P3} on {N1} {N2} ja {N3} {N4}. 
              # Q: Kuinka monta {P2} on {P3} yhteensä? 
              # A: {P1}.
           'numerals1': r".*"
                        r"C\:\s(?P<P3>.+?)\son\s(?P<N1A>.+?)\s(?P<N2A>.+?)\sja\s(?P<N1B>.+?)\s(?P<N2B>.+?)\.\s.*"
                        r"Q\:\sKuinka\smonta\s(?P<P2>.+?)\s.*"
                        r"A:\s(?P<P1>.+?)\."
                        r".*",
              # C: {P3} on {N1A} {P2} ja {N1B} {N2}. Ylvä söi {N1C} vesimelonia. 
              # Q: Kuinka monta vesimelonia on pöydällä? '
              # A: {P1}.        
           'numerals2': r".*"
                        r"C\:\s(?P<P3>.+?)\son\s(?P<N1A>.+?)\s(?P<P2>.+?)\sja\s(?P<N1B>.+?)\s(?P<N2>.+?)\.\s.*söi\s(?P<N1C>.+?)\s.*"
                        r"A:\s(?P<P1>.+?)\."
                        r".*",
              # C: {N2} on {N1} ja {P2} {P1}. 
              # Q: Missä ovat paperit? 
              # A: Tuolin edessä.
           'spatial1': r".*"
                       r"C\:\s(?P<N2>.+?)\s(?:on|ovat)\s(?P<N1>.+?)\sja\s(?P<P2>.+?)\s(?P<P1>.+?)\."
                       r".*",
              # C: {P2} ja {N2} ovat {P1}. Okko laittaa paperit {N1}. 
              # Q: Missä on kynä? 
              # A: Hyllyn päällä.
           'spatial2': r".*"
                       r"C\:\s(?P<P2>.+?)\sja\s(?P<N2>.+?)\s(?:on|ovat)\s(?P<P1>.+?)\.\s\w+\slaittaa\s\w+\s(?P<N1>.+?)\."
                       r".*",
               # C: {P1} ja {N1} olivat {N2} mutta Hellä vaihtoi uraa ja on nyt {P2}. 
               # Q: Kuka on lakimies? 
               # A: Hellä.
           'temporal1': r".*"
                        r"C\:\s(?P<P1>.+?)\sja\s(?P<N1>.+?)\solivat\s(?P<N2>.+?)\smutta\s.*on\snyt\s(?P<P2>.+?)\."
                        r".*",
               # C: {P1} ja {N1} ovat {N2} mutta Jaakko vaihtaa uraa ja tulee olemaan {P2}. 
               # Q: Kuka tulee olemaan kirjanpitäjä? 
               # A: Jaakko.
           'temporal2': r".*"
                        r"C\:\s(?P<P1>.+?)\sja\s(?P<N1>.+?)\sovat\s(?P<N2>.+?)\smutta\s.*ja\stulee\solemaan\s(?P<P2>.+?)\."
                        r".*",
               # C: {N1} on {N2} kuin {P1}. 
               # Q: Kumpi on {P2}? 
               # A: Okko.
           'comparative1': r".*"
                           r"C\:\s(?P<N1>.+?)\son\s(?P<N2>.+?)\skuin\s(?P<P1>.+?)\.\sQ\:\sKumpi\son\s(?P<P2>.+?)\?"
                           r".*",
               # C: Jos kirja olisi pienempi, Jaakko {P2} sitä. Jos {N1} olisi isompi, Jaakko käyttäisi sitä. 
               # Q: Mitä Jaakko käyttäisi jos se olisi vähemmän iso? 
               # A: {P1}.
           'comparative2': r".*"
                           r"C\:\sJos\s\w+.*,\s\w+\s(?P<P2>.+?)\s(?:sitä|sen).\sJos\s(?P<N1>.+?)\solisi\s.*A:\s(?P<P1>.+?)\."
                           r".*",
           },
    'ja': {# {N1}は{P2}(じゃないけど/ではないですが/ございませんが)、{P1}はそうです。
           'negation1': r".*"
                        r"C\:\s(?:(?P<N1A>.+)と(?P<N1B>.+)|(?P<N1>.+))は(?P<P2>.+?)(?:じゃないけど|ではないですが|ではございませんが)、(?:(?P<P1A>.+)と(?P<P1B>.+)|(?P<P1>.+))はそう(?:です|だ|でございます)。"
                        r".*",

           # {N1}は{N2}、{P1}は{P2}だ。
           'negation2': r".*"
                        r"C\:\s(?:(?P<N1A>.+)と(?P<N1B>.+)|(?P<N1>.+))は(?P<N2>.+?)、(?:(?P<P1A>.+)と(?P<P1B>.+)|(?P<P1>.+))は(?P<P2>.+?)(?:だ|です|でございます)。\s?Q\:"
                        r".*",
       
              # C: {P3}に{N1}の{N2}と{N3}の{N4}がある。
              # Q: {P3}にはいくつの{P2}がある？
              # A: {P1}。
           'numerals1': r".*"
                        r"C\:\s(?P<P3>.+?)に(?P<N1A>.+?)の(?P<N2A>.+?)と(?P<N1B>.+?)の(?P<N2B>.+?)が(?:ある|あります|ございます)。.*"
                        r"Q\:\s.*にはいくつの(?P<P2>.+?)が(?:ある|あります|ございます).*"
                        r"A:\s(?P<P1>.+?)(?:です|ございます)?。"
                        r".*",

              # C: {P3}に{N1A}の{P2}と{N1B}の{N2}がございます。富美子はりんごを二個召し上がりました。
              # Q: テーブルの上にりんごはいくつございますか。
              # A: {P1}ございます。        
           'numerals2': r".*"
                        r"C\:\s(?P<P3>.+?)に(?P<N1A>.+?)の(?P<P2>.+?)と(?P<N1B>.+?)の(?P<N2>.+?)が(?:ある|あります|ございます)。.*を(?P<N1C>.+?)(?:食べた|食べました|召し上がりました)。.*"
                        r"A:\s(?P<P1>.+?)(?:です|ございます)?。"
                        r".*",
            # C: {N2}は{N1}、{P2}は{P1}にございます。
            # Q: 紙はどこにございますかか。
            # A: 机の上にございます。
           'spatial1': r".*"
                       r"C\:\s(?P<N2>.+?)は(?P<N1>.+?)、(?P<P2>.+?)は(?P<P1>.+?)に(?:ある|あります|ございます)。"
                       r".*",
            # C: {P2}と{N2}は{P1}にございます。富美子様は電話を{N1}に置かれました。
            # Q: 本はどこにございますか。
            # A: ソファの下にございます。
           'spatial2': r".*"
                       r"C\:\s(?P<P2>.+?)と(?P<N2>.+?)は(?P<P1>.+?)(?:だ|にあります|にございます)。.*を(?P<N1>.+?)に(?:置いた|置きます|置かれました)。"
                       r".*",
            # C: {P1}と{N1}は{N2}でいらっしゃいましたが、笑子様はご転職されて今は{P2}でいらっしゃいます。 
            # Q: 誰が歌手でいらっしゃいますか。
            # A: 笑子様でございます。
           'temporal1': r".*"
                        r"C\:\s(?P<P1>.+?)と(?P<N1>.+?)は(?P<N2>.+?)(?:だった|でした|でいらっしゃいました).*今は(?P<P2>.+?)(?:。|です|でいらっしゃいます)"
                        r".*",
            # C: {P1}と{N1}は{N2}でいらっしゃいますが、春花様はご転職して{P2}になられます。
            # Q: 警官には誰がなられますか。
            # A: 春花様でございます。
           'temporal2': r".*"
                        r"C\:\s(?P<P1>.+?)と(?P<N1>.+?)は(?P<N2>.+?)(?:だけど|ですが|でいらっしゃいますが)、.*転職して(?P<P2>.+?)(?:になる|になります|になられます)。"
                        r".*",
            # C: {N1}は{P1}より{N2}でいらっしゃいます。
            # Q: 誰が{P2}でいらっしゃいますか？
            # A: 実様でございます。
           'comparative1': r".*"
                           r"C\:\s(?P<N1>.+?)は(?P<P1>.+?)より(?P<N2>.+?)(?:。|だ。|です。|でいらっしゃいます。)"
                           r".*Q\:\s(?:どっち|誰|どちら)が(?P<P2>.+?)(?:？|だ|です|でいらっしゃいます)"
                           r".*",
            # C: もしその{P1}がもっと美しかったならば、龍様はそれを{P2}でしょう。もしその{N1}がもっと大きかったならば、龍様はそれを売るでしょう。
            # Q: 何がもっと醜くなかったならば、龍様はそれを売るでしょうか。
            # A: 船でございます。
           'comparative2': r".*"
                           r"C\:\sもしその(?P<P1>.+?)がもっと.*それを(?P<P2>.+?)(?:だろう|でしょう)。もしその(?P<N1>.+?)がもっと"
                           r".*",
            # C: 棚の上に{N1}の物がありますが、それらは辞書です。
            # Q: 棚の上にいくつの辞書がありますか。
            # A: {P1}です。
            'counters': r".*"
                        r"C\:\s(?P<P2>.+?)に(?P<N1>.+?)の物.*A:\s(?P<P1>.+?)(?:。|です。|ございます。)"
                        r".*",
           },
}

CONJ = {"en": "and",
        "de": "und",
        "fi": "ja",
        "ja": "と"}

NEG = {"en": ("not", "no"),
       "de": ("keine", "kein"),
       "fi": ("ei", "eivät"),
       "ja": ("じゃない", "ではない", 
               "じゃありません", "ではありません", 
               "ございません")}

# %%
# NAMES -
#      En - Dennis, Lisa
#      De - Thorsten Marie
#      Fi - Antti, Kati
#      Ja - 昭夫, 文江

# JOBS -
#      En - programmer, therapist
#      De - programmierer, therapeutin
#      Fi - ohjelmoija, terapeutti
#      Ja - プログラマー、療法士

# OBJECT
#      En - bottle, box
#      De - Flasche, Schachtel
#      Fi - pullo, laatikko
#      Ja - ボトル、ボックス

# FRUITS -
#      En - peach, persimmon
#      De - Pfirsich, Dattelpflaume
#      Fi - persikka, persimoni
#      Ja - いちじく、さくらんぼ

# PLACE - 
#      En - drawer, freezer
#      De - Schublade, Gefrierschrank
#      Fi - laatikko, pakastin
#      Ja - 引き出し、冷凍庫

# COMPS -
#      En - wider, thinner
#      De - breiter, dünner
#      Fi - leveämpi, ohuempi
#      Ja - より広い、より薄い

# ACTION -
#      En - discarded
#      De - weggeworfen
#      Fi - olisi hylännyt
#      Ja - 捨てた



ONE_SHOT_PROMPTS = {
                    'en': {'negation1': 'C: Dennis is not a programmer, but Lisa is. Q: Who is a programmer? A: Lisa.', 
                           'negation2': 'C: Dennis is a programmer, Lisa is a therapist. Q: Who is not a programmer? A: Lisa.', 
                           'numerals1': 'C: There are two peaches and six persimmons on the table. Q: How many fruits in total are on the table? A: Eight.', 
                           'numerals2': 'C: There are eight peaches and nine persimmons on the table. Lisa ate two peaches. Q: How many peaches are on the table? A: Six.', 
                           'spatial1': 'C: The bottle is behind the drawer and the box is next to the freezer. Q: Where is the box? A: Next to the freezer.', 
                           'spatial2': 'C: The bottle and the box are behind the drawer. Dennis puts the box on the ground. Q: Where is the bottle? A: Behind the drawer.', 
                           'temporal1': 'C: Dennis and Lisa were writers, but Lisa changed careers and is now a therapist. Q: Who is a therapist? A: Lisa.', 
                           'temporal2': 'C: Dennis and Lisa are writers, but Lisa will change careers and will be a therapist. Q: Who will be a therapist? A: Lisa.', 
                           'comparative1': 'C: Lisa is wider than Dennis. Q: Who is thinner? A: Dennis.', 
                           'comparative2': 'C: If the drawer was wider, Lisa would discard it. If the freezer was thinner, Lisa would discard it. Q: What would Lisa discard if it was less thin? A: The drawer.',
                           }, 
                    'de': {'negation1': 'C: Thorsten ist keine Programmierer, aber Marie ist es. Q: Wer ist Programmierer? A: Lisa.', 
                           'negation2': 'C: Thorsten ist eine Programmierer und Marie ist eine Therapeutin. Q: Wer ist keine Programmierer? A: Marie.', 
                           'numerals1': 'C: Es gibt eine Pfirsich und zwei Dattelpflaume auf dem Tisch. Q: Wie viele Früchte liegen insgesamt auf dem Tisch? A: Drei.', 
                           'numerals2': 'C: Es gibt acht Pfirsich und acht Dattelpflaume auf dem Tisch. Katja aß zwei Pfirsich. Q: Wie viele Pfirsich gibt es auf dem Tisch? A: Sechs.', 
                           'spatial1': 'C: Die Flasche liegt hinter der Schublade und die Schachtel liegen vor dem Gefrierschrank. Q: Wo sind die Schachtel? A: Vor dem Gefrierschrank.', 
                           'spatial2': 'C: Die Flasche und die Schachtel liegen hinter der Schublade. Marie legt die Schachtel auf den Boden. Q: Wo ist die Flasche? A: Hinter der Schublade.', 
                           'temporal1': 'C: Thorsten und Marie waren Programmierer, aber Marie hat den Beruf gewechselt und wird Therapeutin. Q: Wer ist Therapeutin? A: Marie.', 
                           'temporal2': 'C: Thorsten und Marie sind Programmierer, aber Marie wechselt den Beruf und wird Therapeutin. Q: Wer wird Therapeutin? A: Marie.', 
                           'comparative1': 'C: Lisa ist breiter als Thorsten. Q: Wer ist dünner? A: Thorsten.', 
                           'comparative2': 'C: Wäre die Schublade breiter, würde sie Thorsten wegwerfen. Wäre der Gefrierschrank dünner, würde sie Thorsten wegwerfen. Q: Was würde Stefan wegwerfen, wäre es weniger dünn? A: Die Schublade.',
                           }, 
                    'fi': {'negation1': 'C: Antti ei ole ohjelmoija mutta Kati on. Q: Kuka on ohjelmoija? A: Kati.', 
                           'negation2': 'C: Antti on ohjelmoija, Kati on terapeutti. Q: Kuka ei ole ohjelmoija? A: Kati.', 
                           'numerals1': 'C: Pöydällä on yksi persikka ja yksi persimoni. Q: Kuinka monta hedelmää on pöydällä yhteensä? A: Kaksi.', 
                           'numerals2': 'C: Pöydällä on seitsemän persikka ja kahdeksan persimoni. Antti söi yhden persikan. Q: Kuinka monta banaania on pöydällä? A: Kuusi.', 
                           'spatial1': 'C: Pullo on kaapin vieressä ja laatikko pakastimen edessä. Q: Missä on laatikko? A: Pakastimen edessä.', 
                           'spatial2': 'C: Pullo ja laatikko ovat kaapin päällä. Antti laittaa pullo maahan. Q: Missä on laatikko? A: Pakastimen edessä.', 
                           'temporal1': 'C: Antti ja Kati olivat ohjelmoijia mutta Kati vaihtoi uraa ja on nyt terapeutti. Q: Kuka on terapeutti? A: Kati.', 
                           'temporal2': 'C: Antti ja Kati ovat ohjelmoijia mutta Kati vaihtaa uraa ja tulee olemaan terapeutti. Q: Kuka tulee olemaan terapeutti? A: Kati.', 
                           'comparative1': 'C: Kati on leveämpi kuin Antti. Q: Kumpi on ohuempi? A: Antti.', 
                           'comparative2': 'C: Jos laatikko olisi leveämpi, Kati hylkäisi sen. Jos pakastin olisi ohuempi, Kati hylkäisi sen. Q: Mitä Kati hylkäisi jos se olisi vähemmän ohuempi? A: Laatikon.',
                           }, 
                    'ja_fam': {'negation1': 'C: 昭夫はプログラマーじゃないけど、文江はそうだ。 Q: 誰がプログラマー？ A: 文江。', 
                           'negation2': 'C: 昭夫はプログラマー、文江は療法士だ。 Q: プログラマーじゃないのは誰？ A: 文江。', 
                           'numerals1': 'C: テーブルの上に一個のいちじくと一個のさくらんぼがある。 Q: テーブルの上にはいくつの果物がある？ A: 二個。', 
                           'numerals2': 'C: テーブルの上に五個のいちじくと五個のさくらんぼがある。昭夫はいちじくを一個食べた。 Q: テーブルの上にいちじくはいくつある？ A: 四個。', 
                           'spatial1': 'C: ボトルは引き出しの上、ボックスは冷凍庫の前にある。 Q: ボトルはどこ？ A: 引き出しの上。', 
                           'spatial2': 'C: ボトルとボックスは引き出しの上だ。昭夫はボックスを床に置いた。 Q: ボトルはどこ？ A: 引き出しの上。', 
                           'temporal1': 'C: 昭夫と文江はプログラマーだったけど、文江は転職して今は療法士。 Q: 誰が療法士？ A: 文江。', 
                           'temporal2': 'C: 昭夫と文江はプログラマーだけど、文江は転職して療法士になる。 Q: 療法士には誰がなるか？ A: 文江。', 
                           'comparative1': 'C: 昭夫は文江より広い。 Q: どっちが薄い？ A: 文江。', 
                           'comparative2': 'C: もしその引き出しがもっと広かったら、昭夫はそれを捨てるだろう。もしその冷凍庫がもっと薄かったら、昭夫はそれを捨てるだろう。 Q: 何がもっと薄くなかったとしたら、昭夫はそれを捨てるか？ A: 引き出し。',
                           'counters': 'C: 引き出しの隣に四つの物があるが、それは包丁だ。 Q: 引き出しの隣にいくつの包丁がある？ A: 四丁。',},
                     'ja_norm': {'negation1': 'C: 昭夫はプログラマーではないですが、文江はそうです。 Q: 誰がプログラマーですか。 A: 文江です。', 
                           'negation2': 'C: 昭夫はプログラマー、文江は療法士です。 Q: プログラマーでないのは誰ですか。 A: 文江です。', 
                           'numerals1': 'C: テーブルの上に十個のいちじくと十個のさくらんぼがあります。 Q: テーブルの上にはいくつの果物がありますか。 A: 二十個です。', 
                           'numerals2': 'C: テーブルの上に七個のいちじくと九個のさくらんぼがあります。昭夫はいちじくを一個食べました。 Q: テーブルの上にいちじくはいくつありますか。 A: 六個です。', 
                           'spatial1': 'C: ボトルは引き出しの上、ボックスは冷凍庫の前にあります。 Q: ボトルはどこにありますか。 A: 引き出しの上です。', 
                           'spatial2': 'C: ボトルとボックスは引き出しの上にあります。昭夫はボックスを床に置きます。 Q: ボトルはどこにありますか。 A: 引き出しの上。', 
                           'temporal1': 'C: 昭夫と文江はプログラマーでしたが、文江は転職して今は療法士です。 Q: 誰が療法士ですか。 A: 文江です。', 
                           'temporal2': 'C: 昭夫と文江はプログラマーですが、文江は転職して療法士になります。 Q: 療法士には誰がなりますか。 A: 文江です。', 
                           'comparative1': 'C: 昭夫は文江より広いです。 Q: どちらが薄いですか。 A: 文江です。', 
                           'comparative2': 'C: もしその引き出しがもっと広かったら、昭夫はそれを捨てるでしょう。もしその冷凍庫がもっと薄かったら、昭夫はそれを捨てるでしょう。 Q: 何がもっと薄くなかったとしたら、昭夫はそれを捨てますか。 A: 引き出しです。',
                           'counters': 'C: 引き出しの隣に九つの物がありますが、それらは包丁です。 Q: 引き出しの隣にいくつの包丁がありますか。 A: 九丁です。',},
                     'ja_form': {'negation1': 'C: 昭夫様はプログラマーではございませんが、文江様はそうでございます。 Q: 誰がプログラマーでございますか。 A: 文江様でございます。', 
                           'negation2': 'C: 昭夫様はプログラマー、文江様は療法士でございます。 Q: プログラマーでないのは誰でございますか。 A: 文江様でございます。', 
                           'numerals1': 'C: テーブルの上に二個のいちじくと三個のさくらんぼがございます。 Q: テーブルの上にはいくつの果物がございますか。 A: 五個ございます。', 
                           'numerals2': 'C: テーブルの上に八個のいちじくと十個のさくらんぼがございます。昭夫はいちじくを二個召し上がりました。 Q: テーブルの上にいちじくはいくつございますか。 A: 六個ございます。', 
                           'spatial1': 'C: ボトルは引き出しの上、ボックスは冷凍庫の前にございます。 Q: ボトルはどこにございますかか。 A: 引き出しの上にございます。', 
                           'spatial2': 'C: ボトルとボックスは引き出しの上にございます。昭夫様はボックスを床に置かれました。 Q: ボトルはどこにございますか。 A: 引き出しの上にございます。', 
                           'temporal1': 'C: 昭夫様と文江様はプログラマーでいらっしゃいましたが、文江様はご転職されて今は療法士でいらっしゃいます。 Q: 誰が療法士でいらっしゃいますか。 A: 文江様でございます。', 
                           'temporal2': 'C: 昭夫様と文江様はプログラマーでいらっしゃいますが、文江様はご転職して療法士になられます。 Q: 療法士には誰がなられますか。 A: 文江様でございます。', 
                           'comparative1': 'C: 昭夫様は文江様より広いでいらっしゃいます。 Q: 誰が薄いでいらっしゃいますか？ A: 文江様でございます。', 
                           'comparative2': 'C: もしその引き出しがもっと広かったならば、昭夫様はそれを捨てるでしょう。もしその冷凍庫がもっと薄かったならば、昭夫様はそれを捨てるでしょう。 Q: 何がもっと薄くなかったならば、昭夫様はそれを捨てるでしょうか。 A: 引き出しでございます。',
                           'counters': 'C: 引き出しの隣に七つの物がございますが、それらは包丁でございます。 Q: 引き出しの隣にいくつの包丁がございますか。 A: 七丁ございます。',}
                }

ALTERED_ONE_SHOT_PROMPTS = {
                    'en': {'negation1': 'C: Dennis is not a programmer, but Lisa is. Q: Who is not a programmer? A: Dennis.', 
                           'negation2': 'C: Dennis is a programmer, Lisa is a therapist. Q: Who is not a therapist? A: Dennis.', 
                           'numerals1': 'C: There are two peaches and six persimmons on the table. Q: How many fruits in total are on the table? A: Eight.', 
                           'numerals2': 'C: There are eight peaches and nine persimmons on the table. Lisa ate two peaches. Q: How many peaches are on the table? A: Six.', 
                           'spatial1': 'C: The bottle is behind the drawer and the box is next to the freezer. Q: Where is the bottle? A: Behind the drawer.', 
                           'spatial2': 'C: The bottle and the box are behind the drawer. Dennis puts the box on the ground. Q: Where is the box? A: On the ground.', 
                           'temporal1': 'C: Dennis and Lisa were writers, but Lisa changed careers and is now a therapist. Q: Who is a writier? A: Dennis.', 
                           'temporal2': 'C: Dennis and Lisa are writers, but Lisa will change careers and will be a therapist. Q: Who is a writer? A: Dennis and Lisa.', 
                           'comparative1': 'C: Lisa is wider than Dennis. Q: Who is wider? A: Dennis.', 
                           'comparative2': 'C: If the drawer was wider, Lisa would discard it. If the freezer was thinner, Lisa would discard it. Q: What would Lisa discard if it was less wide? A: The freezer.',
                           }, 
                    'de': {'negation1': 'C: Thorsten ist keine Programmierer, aber Marie ist es. Q: Wer ist keine Programmierer? A: Thorsten.', 
                           'negation2': 'C: Thorsten ist eine Programmierer und Marie ist eine Therapeutin. Q: Wer ist keine Therapeutin? A: Thorsten.', 
                           'numerals1': 'C: Es gibt eine Pfirsich und zwei Dattelpflaume auf dem Tisch. Q: Wie viele Früchte liegen insgesamt auf dem Tisch? A: Drei.', 
                           'numerals2': 'C: Es gibt acht Pfirsich und acht Dattelpflaume auf dem Tisch. Katja aß zwei Pfirsich. Q: Wie viele Pfirsich gibt es auf dem Tisch? A: Sechs.', 
                           'spatial1': 'C: Die Flasche liegt hinter der Schublade und die Schachtel liegen vor dem Gefrierschrank. Q: Wo sind die Flasche? A: Hinter der Schublade.', 
                           'spatial2': 'C: Die Flasche und die Schachtel liegen hinter der Schublade. Marie legt die Schachtel auf den Boden. Q: Wo ist die Schachtel? A: Auf den Boden.', 
                           'temporal1': 'C: Thorsten und Marie waren Programmierer, aber Marie hat den Beruf gewechselt und wird Therapeutin. Q: Wer ist Programmierer? A: Thorsten.', 
                           'temporal2': 'C: Thorsten und Marie sind Programmierer, aber Marie wechselt den Beruf und wird Therapeutin. Q: Wer ist Programmierer? A: Thorsten und Marie.', 
                           'comparative1': 'C: Lisa ist breiter als Thorsten. Q: Wer ist breiter? A: Lisa.', 
                           'comparative2': 'C: Wäre die Schublade breiter, würde sie Thorsten wegwerfen. Wäre der Gefrierschrank dünner, würde sie Thorsten wegwerfen. Q: Was würde Stefan wegwerfen, wäre es weniger breit? A: Der Gefrierschrank.',
                           }, 
                    'fi': {'negation1': 'C: Antti ei ole ohjelmoija mutta Kati on. Q: Kuka ei ole ohjelmoija? A: Antti.', 
                           'negation2': 'C: Antti on ohjelmoija, Kati on terapeutti. Q: Kuka ei ole terapeutti? A: Antti.', 
                           'numerals1': 'C: Pöydällä on yksi persikka ja yksi persimoni. Q: Kuinka monta hedelmää on pöydällä yhteensä? A: Kaksi.', 
                           'numerals2': 'C: Pöydällä on seitsemän persikka ja kahdeksan persimoni. Antti söi yhden persikan. Q: Kuinka monta banaania on pöydällä? A: Kuusi.', 
                           'spatial1': 'C: Pullo on kaapin vieressä ja laatikko pakastimen edessä. Q: Missä on pullo? A: Kaapin vieressä.', 
                           'spatial2': 'C: Pullo ja laatikko ovat kaapin päällä. Antti laittaa pullo maahan. Q: Missä on pullo? A: Maahan.', 
                           'temporal1': 'C: Antti ja Kati olivat ohjelmoijia mutta Kati vaihtoi uraa ja on nyt terapeutti. Q: Kuka on ohjelmoijia? A: Antti.', 
                           'temporal2': 'C: Antti ja Kati ovat ohjelmoijia mutta Kati vaihtaa uraa ja tulee olemaan terapeutti. Q: Kuka on ohjelmoijia? A: Antti ja Kati.', 
                           'comparative1': 'C: Kati on leveämpi kuin Antti. Q: Kumpi on leveämpi? A: Kati.', 
                           'comparative2': 'C: Jos laatikko olisi leveämpi, Kati hylkäisi sen. Jos pakastin olisi ohuempi, Kati hylkäisi sen. Q: Mitä Kati hylkäisi jos se olisi vähemmän leveämpi? A: Pakastin.',
                           }, 
                    'ja_fam': {'negation1': 'C: 昭夫はプログラマーじゃないけど、文江はそうだ。 Q: 誰がプログラマーじゃない？ A: 昭夫。', 
                           'negation2': 'C: 昭夫はプログラマー、文江は療法士だ。 Q: 療法士じゃないのは誰？ A: 昭夫。', 
                           'numerals1': 'C: テーブルの上に一個のいちじくと一個のさくらんぼがある。 Q: テーブルの上にはいくつの果物がある？ A: 二個。', 
                           'numerals2': 'C: テーブルの上に五個のいちじくと五個のさくらんぼがある。昭夫はいちじくを一個食べた。 Q: テーブルの上にいちじくはいくつある？。 A: 四個。', 
                           'spatial1': 'C: ボトルは引き出しの上、ボックスは冷凍庫の前にある。 Q: ボックスはどこ？ A: 冷凍庫の前。', 
                           'spatial2': 'C: ボトルとボックスは引き出しの上だ。昭夫はボックスを床に置いた。 Q: ボックスはどこ？ A: 床に。', 
                           'temporal1': 'C: 昭夫と文江はプログラマーだったけど、文江は転職して今は療法士。 Q: 誰がプログラマー？ A: 昭夫。', 
                           'temporal2': 'C: 昭夫と文江はプログラマーだけど、文江は転職して療法士になる。 Q: 誰がプログラマー？ A: 昭夫と文江。', 
                           'comparative1': 'C: 昭夫は文江より広い。 Q: どっちが広い？ A: 昭夫。', 
                           'comparative2': 'C: もしその引き出しがもっと広かったら、昭夫はそれを捨てるだろう。もしその冷凍庫がもっと薄かったら、昭夫はそれを捨てるだろう。 Q: 何がもっと広くなかったとしたら、昭夫はそれを捨てるか。 A: 冷凍庫。',
                           'counters': 'C: 引き出しの隣に四つの物があるが、それは包丁だ。 Q: 引き出しの隣にいくつの包丁がある？ A: 四丁。',},
                     'ja_norm': {'negation1': 'C: 昭夫はプログラマーではないですが、文江はそうです。 Q: 誰がプログラマーではないか。 A: 昭夫です。', 
                           'negation2': 'C: 昭夫はプログラマー、文江は療法士です。 Q: 療法士でないのは誰ですか。 A: 昭夫です。', 
                           'numerals1': 'C: テーブルの上に十個のいちじくと十個のさくらんぼがあります。 Q: テーブルの上にはいくつの果物がありますか。 A: 二十個です。', 
                           'numerals2': 'C: テーブルの上に七個のいちじくと九個のさくらんぼがあります。昭夫はいちじくを一個食べました。 Q: テーブルの上にいちじくはいくつありますか。 A: 六個です。', 
                           'spatial1': 'C: ボトルは引き出しの上、ボックスは冷凍庫の前にあります。 Q: ボックスはどこにありますか。 A: 冷凍庫の前です。', 
                           'spatial2': 'C: ボトルとボックスは引き出しの上にあります。昭夫はボックスを床に置きます。 Q: ボックスはどこにありますか。 A: 床にあります。', 
                           'temporal1': 'C: 昭夫と文江はプログラマーでしたが、文江は転職して今は療法士です。 Q: 誰がプログラマーですか。 A: 昭夫です。', 
                           'temporal2': 'C: 昭夫と文江はプログラマーですが、文江は転職して療法士になります。 Q: 誰がプログラマーですか。 A: 昭夫と文江です。', 
                           'comparative1': 'C: 昭夫は文江より広いです。 Q: どちらが広いですか。 A: 昭夫です。', 
                           'comparative2': 'C: もしその引き出しがもっと広かったら、昭夫はそれを捨てるでしょう。もしその冷凍庫がもっと薄かったら、昭夫はそれを捨てるでしょう。 Q: 何がもっと広くなかったとしたら、昭夫はそれを捨てますか。 A: 冷凍庫です。',
                           'counters': 'C: 引き出しの隣に九つの物がありますが、それらは包丁です。 Q: 引き出しの隣にいくつの包丁がありますか。 A: 九丁です。',},
                     'ja_form': {'negation1': 'C: 昭夫様はプログラマーではございませんが、文江様はそうでございます。 Q: 誰がプログラマーでございませんか。 A: 昭夫様でございます。', 
                           'negation2': 'C: 昭夫様はプログラマー、文江様は療法士でございます。 Q: 療法士でないのは誰でございますか。 A: 昭夫様でございます。', 
                           'numerals1': 'C: テーブルの上に二個のいちじくと三個のさくらんぼがございます。 Q: テーブルの上にはいくつの果物がございますか。 A: 五個ございます。', 
                           'numerals2': 'C: テーブルの上に八個のいちじくと十個のさくらんぼがございます。昭夫はいちじくを二個召し上がりました。 Q: テーブルの上にいちじくはいくつございますか。 A: 六個ございます。', 
                           'spatial1': 'C: ボトルは引き出しの上、ボックスは冷凍庫の前にございます。 Q: ボックスはどこにございますかか。 A: 冷凍庫の前にございます。', 
                           'spatial2': 'C: ボトルとボックスは引き出しの上にございます。昭夫様はボックスを床に置かれました。 Q: ボックスはどこにございますか。 A: 床にございます。', 
                           'temporal1': 'C: 昭夫様と文江様はプログラマーでいらっしゃいましたが、文江様はご転職されて今は療法士でいらっしゃいます。 Q: 誰がプログラマーでいらっしゃいますか。 A: 昭夫様でございます。', 
                           'temporal2': 'C: 昭夫様と文江様はプログラマーでいらっしゃいますが、文江様はご転職して療法士になられます。 Q: 誰がプログラマーでいらっしゃいますか。 A: 昭夫様と文江様でございます。', 
                           'comparative1': 'C: 昭夫様は文江様より広いでいらっしゃいます。 Q: 誰が広いでいらっしゃいますか？ A: 昭夫様でございます。', 
                           'comparative2': 'C: もしその引き出しがもっと広かったならば、昭夫様はそれを捨てるでしょう。もしその冷凍庫がもっと薄かったならば、昭夫様はそれを捨てるでしょう。 Q: 何がもっと広くなかったならば、昭夫様はそれを捨てるでしょうか。 A: 冷凍庫でございます。',
                           'counters': 'C: 引き出しの隣に七つの物がございますが、それらは包丁でございます。 Q: 引き出しの隣にいくつの包丁がございますか。 A: 七丁ございます。',}
                }

PREFIX = {'ja_fam': '日本語でお答えて。',
                          'ja_form': '日本語でお答えください。',
                          'ja_norm': '日本語で答えてください。',
                          'en': 'Please answer the question in English.',
                          'de': 'Bitte beantworten Sie die Frage auf Deutsch.',
                          'fi': 'Vastaa kysymykseen suomeksi.'}

KEYS = {'ja': {'C': '文脈', 'Q': '質問', 'A': '回答'},
       'en': {'C': 'Context', 'Q': 'Question', 'A': 'Answer'},
       'de': {'C': 'Kontext', 'Q': 'Frage', 'A': 'Antwort'},
       'fi': {'C': 'Konteksti', 'Q': 'Kysymys', 'A': 'Vastaus'},}

# %%
import re

def get_targets(prompt, lang, task):
    groups = re.search(TARGET_PATTERN[lang][task], prompt)
    if not groups:
        print(task)
        print(lang)
        print(prompt)
    
    targets = {k: v.lower() for k, v in groups.groupdict().items() if v}
    # if task in {'negation1', 'negation2'}: 
    #     new_items = {}
    #     remove_keys = []
    #     for k, v in targets.items():
    #         if CONJ[lang] in v:
    #             print(v)
    #             v1, v2 = v.split(CONJ[lang] if lang == 'ja' else f' {CONJ[lang]} ')
    #             new_items[k+'A'], new_items[k+'B'] = v1.strip(), v2.strip()
    #             remove_keys.append(k)
    #     targets.update(new_items)
    #     for k in remove_keys:
    #         del targets[k]

    return targets

# %%
import json
import os
from collections import Counter
path = '/home/norrman/GitHub/multi-morph-checklist/M2C.json'

if not os.path.isfile(path):
    data = {}
    ind = 0
    for doc in files:
        with open(doc['path'], 'r') as f:
            for line in f:
                context, question, answer = line.strip().replace('C: ', '').replace('Q: ', '|').replace('A: ', '|').split('|')
                context, question, answer = context.strip(), question.strip(), answer.strip()
                lang, task, polite = doc['lang'], doc['task'], doc['polite']
                lang_p = lang + f'_{polite}' if polite else lang

                data[ind] = {
                              'task': task,
                              'lang': lang_p,
                              'prefix': PREFIX[lang_p],
                              'context': context.strip(),
                              'question': question.strip(),
                              'answer': answer.strip(),
                              'prompt': f"{KEYS[lang]['C']}: {context} {KEYS[lang]['Q']}: {question} {KEYS[lang]['A']}:",
                              'targets': get_targets(line, lang, task),
                              'example_prompt': ONE_SHOT_PROMPTS[lang_p][task].replace('C: ', KEYS[lang]['C']+': ').replace('Q: ', KEYS[lang]['Q']+': ').replace('A: ', KEYS[lang]['A']+': '),
                              'altered_example_prompt': ALTERED_ONE_SHOT_PROMPTS[lang_p][task].replace('C: ', KEYS[lang]['C']+': ').replace('Q: ', KEYS[lang]['Q']+': ').replace('A: ', KEYS[lang]['A']+': '),
                              'raw_response': {},
                              'response': {}
                            }
                
                ind += 1
    counts = Counter([d['lang'] for d in data.values()])
    print(counts)
    json.dump(data, open(path, 'w'), indent=4)
else:
    print('ERROR: OUTFILE ALREADY EXISTS')
# Out:
# Counter({'ja_fam': 5500, 'ja_norm': 5500, 'ja_form': 5500, 'en': 5000, 'de': 5000, 'fi': 5000})

# %% [markdown]
# ## Post Processing Responses

# %%
import json

data = json.load(open('/home/norrman/GitHub/multi-morph-checklist/M2C_responses.json'))

# %%
for id, item in data.items():
    # item['response']["xlm_oneshot_2beam"] = item['response']["xlm_oneshot_1beam"]
    # del item['response']["xlm_oneshot_1beam"]

    for k, v in item['response'].items():
        if k == "xglm_oneshot_altex_1beam":
            prompt = f"{item['prefix']} {item['altered_example_prompt'] }"
            item['response'][k] = v[len(prompt):]
        elif k == "xglm_oneshot_altex_2beam": 
            prompt = f"{item['prefix']} {item['altered_example_prompt']}"
            item['response'][k] = v[len(prompt):]
        elif k == "xlm_oneshot_1beam":
            prompt = f"{item['prefix']} {item['example_prompt']}"
            item['response'][k] = v[len(prompt):]
        elif k == "xlm_oneshot_2beam":
            prompt = f"{item['prefix']} {item['example_prompt']}"
            item['response'][k] = v[len(prompt):]
        elif k == "xlm_zeroshot_1beam": 
            prompt = f"{item['prefix']}"
            item['response'][k] = v[len(prompt):]
        elif k == "xlm_zeroshot_2beam":
            prompt = f"{item['prefix']}"
            item['response'][k] = v[len(prompt):]

data
# Out:
# {'0': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Susan is not an architect, but Lola is. ',
#   'question': 'Who is an architect? ',
#   'answer': 'Lola.',
#   'prompt': 'Context: Susan is not an architect, but Lola is.  Question: Who is an architect?  Answer:',
#   'targets': {'N1': 'susan', 'P2': 'architect', 'P1': 'lola'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Susan. Context: Susan is not an architect.',
#    'xglm_oneshot_altex_2beam': ' Susan. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_oneshot_1beam': 'Lola. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Susan is an architect.',
#    'xlm_zeroshot_2beam': ' Susan is an architect, Lola is an architect, and Susan is an architect'}},
#  '1': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'John is not a lawyer, but Sophia and Charlotte are. ',
#   'question': 'Who are lawyers? ',
#   'answer': 'Sophia and Charlotte.',
#   'prompt': 'Context: John is not a lawyer, but Sophia and Charlotte are.  Question: Who are lawyers?  Answer:',
#   'targets': {'N1': 'john',
#    'P2': 'lawyer',
#    'P1A': 'sophia',
#    'P1B': 'charlotte'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' John. Context: John is not a lawyer, but Sophia and Charlotte',
#    'xglm_oneshot_altex_2beam': ' John. Context: John is not a lawyer, but Sophia and Charlotte',
#    'xlm_oneshot_1beam': 'Sophia. Context: John is not a lawyer, but Sophia and Charlotte',
#    'xlm_zeroshot_1beam': ' John is a lawyer.',
#    'xlm_zeroshot_2beam': ' John is not a lawyer, but Sophia and Charlotte are.'}},
#  '2': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Kirk is not a scientist, but Robert is. ',
#   'question': 'Who is a scientist? ',
#   'answer': 'Robert.',
#   'prompt': 'Context: Kirk is not a scientist, but Robert is.  Question: Who is a scientist?  Answer:',
#   'targets': {'N1': 'kirk', 'P2': 'scientist', 'P1': 'robert'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Kirk. Context: Kirk is not a scientist, but Robert is.',
#    'xglm_oneshot_altex_2beam': ' Kirk. Context: Kirk is not a scientist, but Robert is.',
#    'xlm_oneshot_1beam': 'Robert. Context: Kirk is not a scientist, but Robert is.',
#    'xlm_zeroshot_1beam': ' Robert Kirk is a scientist.',
#    'xlm_zeroshot_2beam': ' Robert Kirk is a scientist.'}},
#  '3': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not a farmer, but Lily is. ',
#   'question': 'Who is a farmer? ',
#   'answer': 'Lily.',
#   'prompt': 'Context: Mary is not a farmer, but Lily is.  Question: Who is a farmer?  Answer:',
#   'targets': {'N1': 'mary', 'P2': 'farmer', 'P1': 'lily'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Mary. Context: Lily is not a farmer, but Lily is.',
#    'xglm_oneshot_altex_2beam': ' Lily. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_oneshot_1beam': 'Lily. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Mary is a farmer.',
#    'xlm_zeroshot_2beam': ' Mary is a farmer, and Lily is a farmer.'}},
#  '4': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'James is not a writer, but Paul and Bob are. ',
#   'question': 'Who are writers? ',
#   'answer': 'Paul and Bob.',
#   'prompt': 'Context: James is not a writer, but Paul and Bob are.  Question: Who are writers?  Answer:',
#   'targets': {'N1': 'james', 'P2': 'writer', 'P1A': 'paul', 'P1B': 'bob'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' James. Context: Paul and Bob.',
#    'xglm_oneshot_altex_2beam': ' Paul and Bob. Context: Dennis is not a programmer, but Lisa',
#    'xlm_oneshot_1beam': 'Paul and Bob. Context: Paul and Bob. Context: Paul',
#    'xlm_zeroshot_1beam': ' James is a writer.',
#    'xlm_zeroshot_2beam': ' James is a writer, but Paul and Bob are writers.'}},
#  '5': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Audrey is not a doctor, but Olivia and Emily are. ',
#   'question': 'Who are doctors? ',
#   'answer': 'Olivia and Emily.',
#   'prompt': 'Context: Audrey is not a doctor, but Olivia and Emily are.  Question: Who are doctors?  Answer:',
#   'targets': {'N1': 'audrey', 'P2': 'doctor', 'P1A': 'olivia', 'P1B': 'emily'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Audrey. Context: Audrey is not a doctor, but Olivia',
#    'xglm_oneshot_altex_2beam': ' Audrey. Context: Audrey is not a doctor, but Olivia',
#    'xlm_oneshot_1beam': 'Audrey. Context: Audrey is not a doctor, but Olivia',
#    'xlm_zeroshot_1beam': ' Audrey is a doctor. Emily is a nurse.',
#    'xlm_zeroshot_2beam': ' Audrey is not a doctor, but Olivia and Emily are.'}},
#  '6': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'James is not a farmer, but Eleanor and Lillian are. ',
#   'question': 'Who are farmers? ',
#   'answer': 'Eleanor and Lillian.',
#   'prompt': 'Context: James is not a farmer, but Eleanor and Lillian are.  Question: Who are farmers?  Answer:',
#   'targets': {'N1': 'james',
#    'P2': 'farmer',
#    'P1A': 'eleanor',
#    'P1B': 'lillian'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' James. Context: James is not a farmer, but Eleanor and',
#    'xglm_oneshot_altex_2beam': ' James. Context: James is not a farmer, but Eleanor and',
#    'xlm_oneshot_1beam': 'Eleanor. Context: James is not a farmer, but Eleanor',
#    'xlm_zeroshot_1beam': ' James is a farmer.',
#    'xlm_zeroshot_2beam': ' James is a farmer. Eleanor and Lillian are farmers.'}},
#  '7': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Audrey is not a waitress, but Eleanor and Lillian are. ',
#   'question': 'Who are waiters? ',
#   'answer': 'Eleanor and Lillian.',
#   'prompt': 'Context: Audrey is not a waitress, but Eleanor and Lillian are.  Question: Who are waiters?  Answer:',
#   'targets': {'N1': 'audrey',
#    'P2': 'waitress',
#    'P1A': 'eleanor',
#    'P1B': 'lillian'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Audrey. Context: Audrey is a waitress, but',
#    'xglm_oneshot_altex_2beam': ' Audrey. Context: Audrey is not a waitress,',
#    'xlm_oneshot_1beam': 'Eleanor. Context: Audrey is not a waitress,',
#    'xlm_zeroshot_1beam': ' Audrey is a waitress.',
#    'xlm_zeroshot_2beam': ' Audrey is a waitress, and Lillian is a waitres'}},
#  '8': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Emma and Monica are not writers, but Eleanor and Lillian are. ',
#   'question': 'Who are writers? ',
#   'answer': 'Eleanor and Lillian.',
#   'prompt': 'Context: Emma and Monica are not writers, but Eleanor and Lillian are.  Question: Who are writers?  Answer:',
#   'targets': {'N1A': 'emma',
#    'N1B': 'monica',
#    'P2': 'writers',
#    'P1A': 'eleanor',
#    'P1B': 'lillian'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Eleanor. Context: Dennis is not a programmer, but Lisa is',
#    'xglm_oneshot_altex_2beam': ' Eleanor. Context: Dennis is not a programmer, but Lisa is',
#    'xlm_oneshot_1beam': 'Eleanor and Lillian.',
#    'xlm_zeroshot_1beam': ' Emma and Monica are not writers, but Eleanor and Lillian are.',
#    'xlm_zeroshot_2beam': ' Emma and Monica are not writers, but Eleanor and Lillian are.'}},
#  '9': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lily is not a waitress, but Steve is. ',
#   'question': 'Who is a waiter? ',
#   'answer': 'Steve.',
#   'prompt': 'Context: Lily is not a waitress, but Steve is.  Question: Who is a waiter?  Answer:',
#   'targets': {'N1': 'lily', 'P2': 'waitress', 'P1': 'steve'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Steve. Context: Dennis is not a waiter, but Lisa is',
#    'xglm_oneshot_altex_2beam': ' Steve. Context: Lisa is not a waitress, but Lisa',
#    'xlm_oneshot_1beam': 'Steve. Context: Steve. Context: Steve. Context:',
#    'xlm_zeroshot_1beam': ' Lily is a waitress.',
#    'xlm_zeroshot_2beam': ' Lily is a waitress, but Steve is a waiter.'}},
#  '10': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Robert is not a lawyer, but Mark and Andrew are. ',
#   'question': 'Who are lawyers? ',
#   'answer': 'Mark and Andrew.',
#   'prompt': 'Context: Robert is not a lawyer, but Mark and Andrew are.  Question: Who are lawyers?  Answer:',
#   'targets': {'N1': 'robert', 'P2': 'lawyer', 'P1A': 'mark', 'P1B': 'andrew'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Robert. Context: Mark. Context: Andrew. Context:',
#    'xglm_oneshot_altex_2beam': ' Robert. Context: Mark. Context: Andrew. Context:',
#    'xlm_oneshot_1beam': 'Mark. Context: Mark. Context: Mark. Context:',
#    'xlm_zeroshot_1beam': ' Robert is a lawyer. Mark is a lawyer. Mark is a lawyer.',
#    'xlm_zeroshot_2beam': ' Robert is a lawyer. Mark is a lawyer. Mark is a lawyer.'}},
#  '11': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Audrey is not an actress, but Alice and Harper are. ',
#   'question': 'Who are actors? ',
#   'answer': 'Alice and Harper.',
#   'prompt': 'Context: Audrey is not an actress, but Alice and Harper are.  Question: Who are actors?  Answer:',
#   'targets': {'N1': 'audrey',
#    'P2': 'actress',
#    'P1A': 'alice',
#    'P1B': 'harper'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Audrey. Context: Audrey is not a singer, but Alice',
#    'xglm_oneshot_altex_2beam': ' Audrey. Context: Audrey is not an actress, but Alice',
#    'xlm_oneshot_1beam': 'Audrey. Context: Audrey is not an actress, but Alice',
#    'xlm_zeroshot_1beam': ' Audrey is an actress, but Alice and Harper are.',
#    'xlm_zeroshot_2beam': ' Audrey is an actress, but Alice and Harper are actors.'}},
#  '12': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lily is not an accountant, but Joseph and Thomas are. ',
#   'question': 'Who are accountants? ',
#   'answer': 'Joseph and Thomas.',
#   'prompt': 'Context: Lily is not an accountant, but Joseph and Thomas are.  Question: Who are accountants?  Answer:',
#   'targets': {'N1': 'lily',
#    'P2': 'accountant',
#    'P1A': 'joseph',
#    'P1B': 'thomas'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Joseph. Context: Thomas. Context: Joseph. Context:',
#    'xglm_oneshot_altex_2beam': ' Joseph. Context: Thomas. Context: Joseph. Context:',
#    'xlm_oneshot_1beam': 'Joseph and Thomas. Context: Joseph and Thomas. Context: Joseph',
#    'xlm_zeroshot_1beam': ' Joseph is a lawyer. Question: Who are accountants? Answer: Thomas',
#    'xlm_zeroshot_2beam': ' Accountants are accountants.'}},
#  '13': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Rachel is not a writer, but Steve is. ',
#   'question': 'Who is a writer? ',
#   'answer': 'Steve.',
#   'prompt': 'Context: Rachel is not a writer, but Steve is.  Question: Who is a writer?  Answer:',
#   'targets': {'N1': 'rachel', 'P2': 'writer', 'P1': 'steve'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Steve. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Steve. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_oneshot_1beam': 'Steve. Context: Lisa is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Rachel is a writer.',
#    'xlm_zeroshot_2beam': ' Rachel is a writer, but Steve is a writer.'}},
#  '14': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'John is not a scientist, but Paul and Bob are. ',
#   'question': 'Who are scientists? ',
#   'answer': 'Paul and Bob.',
#   'prompt': 'Context: John is not a scientist, but Paul and Bob are.  Question: Who are scientists?  Answer:',
#   'targets': {'N1': 'john', 'P2': 'scientist', 'P1A': 'paul', 'P1B': 'bob'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Paul and Bob. Context: Dennis is not a scientist, but Paul',
#    'xglm_oneshot_altex_2beam': ' Paul and Bob. Context: Dennis is not a programmer, but Lisa',
#    'xlm_oneshot_1beam': 'Paul and Bob. Context: Paul and Bob. Context: Paul',
#    'xlm_zeroshot_1beam': ' John is a scientist.',
#    'xlm_zeroshot_2beam': ' John is a scientist, but Paul and Bob are scientists.'}},
#  '15': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lily is not an actress, but Eleanor and Lillian are. ',
#   'question': 'Who are actors? ',
#   'answer': 'Eleanor and Lillian.',
#   'prompt': 'Context: Lily is not an actress, but Eleanor and Lillian are.  Question: Who are actors?  Answer:',
#   'targets': {'N1': 'lily',
#    'P2': 'actress',
#    'P1A': 'eleanor',
#    'P1B': 'lillian'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Dennis. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Dennis. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_oneshot_1beam': 'Lily. Context: Lily is not an actress, but Eleanor and',
#    'xlm_zeroshot_1beam': ' Lily is an actress.',
#    'xlm_zeroshot_2beam': ' Lily is an actress, but Eleanor and Lillian are actors.'}},
#  '16': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lola is not a policewoman, but James is. ',
#   'question': 'Who is a policeman? ',
#   'answer': 'James.',
#   'prompt': 'Context: Lola is not a policewoman, but James is.  Question: Who is a policeman?  Answer:',
#   'targets': {'N1': 'lola', 'P2': 'policewoman', 'P1': 'james'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' James. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' James. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_oneshot_1beam': 'James. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' James is a policeman.',
#    'xlm_zeroshot_2beam': ' James is a policeman. Context: James is a policeman.'}},
#  '17': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not a doctor, but Mark and Andrew are. ',
#   'question': 'Who are doctors? ',
#   'answer': 'Mark and Andrew.',
#   'prompt': 'Context: Mary is not a doctor, but Mark and Andrew are.  Question: Who are doctors?  Answer:',
#   'targets': {'N1': 'mary', 'P2': 'doctor', 'P1A': 'mark', 'P1B': 'andrew'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Mary. Context: Mark. Context: Andrew. Context:',
#    'xglm_oneshot_altex_2beam': ' Mary. Context: Mark. Context: Andrew. Context:',
#    'xlm_oneshot_1beam': 'Mark. Context: Mark. Context: Mark. Context:',
#    'xlm_zeroshot_1beam': ' Mary is a doctor. Mark is a doctor. Andrew is a doctor.',
#    'xlm_zeroshot_2beam': ' Mary is not a doctor, but Mark and Andrew are.'}},
#  '18': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Susan is not a teacher, but Steve is. ',
#   'question': 'Who is a teacher? ',
#   'answer': 'Steve.',
#   'prompt': 'Context: Susan is not a teacher, but Steve is.  Question: Who is a teacher?  Answer:',
#   'targets': {'N1': 'susan', 'P2': 'teacher', 'P1': 'steve'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Susan. Context: Steve is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Susan. Context: Steve is not a programmer, but Lisa is.',
#    'xlm_oneshot_1beam': 'Steve. Context: Susan is not a teacher, but Steve is.',
#    'xlm_zeroshot_1beam': ' Susan is a teacher.',
#    'xlm_zeroshot_2beam': ' Susan is a teacher. Steve is a teacher. Susan is a teacher.'}},
#  '19': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lily is not an actress, but Ross and Joey are. ',
#   'question': 'Who are actors? ',
#   'answer': 'Ross and Joey.',
#   'prompt': 'Context: Lily is not an actress, but Ross and Joey are.  Question: Who are actors?  Answer:',
#   'targets': {'N1': 'lily', 'P2': 'actress', 'P1A': 'ross', 'P1B': 'joey'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Dennis. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Ross and Joey. Context: Dennis is not a programmer, but',
#    'xlm_oneshot_1beam': 'Ross and Joey. Context: Ross and Joey. Context',
#    'xlm_zeroshot_1beam': ' Lily is an actress.',
#    'xlm_zeroshot_2beam': ' Ross and Joey are actors, but Lily is not an actress.'}},
#  '20': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Olivia and Emily are not actresses, but Ross and Joey are. ',
#   'question': 'Who are actors? ',
#   'answer': 'Ross and Joey.',
#   'prompt': 'Context: Olivia and Emily are not actresses, but Ross and Joey are.  Question: Who are actors?  Answer:',
#   'targets': {'N1A': 'olivia',
#    'N1B': 'emily',
#    'P2': 'actresses',
#    'P1A': 'ross',
#    'P1B': 'joey'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Ross. Context: Ross and Joey are not actors.',
#    'xglm_oneshot_altex_2beam': ' Dennis. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_oneshot_1beam': 'Ross and Joey. Context: Ross and Joey are not actors',
#    'xlm_zeroshot_1beam': ' Ross and Joey are actors.',
#    'xlm_zeroshot_2beam': ' Ross and Joey are actors, but Olivia and Emily are actresses.'}},
#  '21': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'John is not a policeman, but Joseph and Thomas are. ',
#   'question': 'Who are policemen? ',
#   'answer': 'Joseph and Thomas.',
#   'prompt': 'Context: John is not a policeman, but Joseph and Thomas are.  Question: Who are policemen?  Answer:',
#   'targets': {'N1': 'john',
#    'P2': 'policeman',
#    'P1A': 'joseph',
#    'P1B': 'thomas'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' John. Context: John is not a policeman, but Joseph and',
#    'xglm_oneshot_altex_2beam': ' John. Context: John is not a policeman, but Joseph and',
#    'xlm_oneshot_1beam': 'John. Context: John is not a policeman, but Joseph and',
#    'xlm_zeroshot_1beam': ' John is a policeman.',
#    'xlm_zeroshot_2beam': ' John is a policeman, but Joseph and Thomas are.'}},
#  '22': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Steve is not a singer, but Clark is. ',
#   'question': 'Who is a singer? ',
#   'answer': 'Clark.',
#   'prompt': 'Context: Steve is not a singer, but Clark is.  Question: Who is a singer?  Answer:',
#   'targets': {'N1': 'steve', 'P2': 'singer', 'P1': 'clark'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Clark. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Clark. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_oneshot_1beam': 'Clark. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Steve is a singer.',
#    'xlm_zeroshot_2beam': ' Steve is not a singer, but Clark is.'}},
#  '23': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Olivia and Emily are not architects, but Christopher and Charles are. ',
#   'question': 'Who are architects? ',
#   'answer': 'Christopher and Charles.',
#   'prompt': 'Context: Olivia and Emily are not architects, but Christopher and Charles are.  Question: Who are architects?  Answer:',
#   'targets': {'N1A': 'olivia',
#    'N1B': 'emily',
#    'P2': 'architects',
#    'P1A': 'christopher',
#    'P1B': 'charles'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Christopher. Context: Christopher and Charles are not architects.',
#    'xglm_oneshot_altex_2beam': ' Christopher and Charles. Context: Dennis is not a programmer, but Lisa',
#    'xlm_oneshot_1beam': 'Christopher and Charles. Context: Christopher and Charles. Context: Christopher',
#    'xlm_zeroshot_1beam': ' Christopher and Charles are architects.',
#    'xlm_zeroshot_2beam': ' Christopher and Charles are architects.'}},
#  '24': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Steve is not a farmer, but Mark and Andrew are. ',
#   'question': 'Who are farmers? ',
#   'answer': 'Mark and Andrew.',
#   'prompt': 'Context: Steve is not a farmer, but Mark and Andrew are.  Question: Who are farmers?  Answer:',
#   'targets': {'N1': 'steve', 'P2': 'farmer', 'P1A': 'mark', 'P1B': 'andrew'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Steve. Context: Mark. Context: Andrew. Context:',
#    'xglm_oneshot_altex_2beam': ' Steve. Context: Mark. Context: Andrew. Context:',
#    'xlm_oneshot_1beam': 'Mark. Context: Andrew is not a farmer, but Mark and Andrew',
#    'xlm_zeroshot_1beam': ' Steve is a farmer. Mark is a farmer. Mark is a farmer.',
#    'xlm_zeroshot_2beam': ' Steve is a farmer. Mark is a farmer. Andrew is a farmer.'}},
#  '25': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Rachel is not a policewoman, but Robert is. ',
#   'question': 'Who is a policeman? ',
#   'answer': 'Robert.',
#   'prompt': 'Context: Rachel is not a policewoman, but Robert is.  Question: Who is a policeman?  Answer:',
#   'targets': {'N1': 'rachel', 'P2': 'policewoman', 'P1': 'robert'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Robert. Context: Rachel. Context: Robert. Context:',
#    'xglm_oneshot_altex_2beam': ' Robert. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_oneshot_1beam': 'Robert. Context: Rachel is not a policewoman, but Robert is',
#    'xlm_zeroshot_1beam': ' Rachel is a policewoman.',
#    'xlm_zeroshot_2beam': ' Rachel is a policewoman. Robert is a policeman.'}},
#  '26': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Robert is not a lawyer, but Paul and Bob are. ',
#   'question': 'Who are lawyers? ',
#   'answer': 'Paul and Bob.',
#   'prompt': 'Context: Robert is not a lawyer, but Paul and Bob are.  Question: Who are lawyers?  Answer:',
#   'targets': {'N1': 'robert', 'P2': 'lawyer', 'P1A': 'paul', 'P1B': 'bob'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Paul and Bob. Context: Dennis is not a lawyer, but Paul',
#    'xglm_oneshot_altex_2beam': ' Paul and Bob. Context: Paul and Bob. Context: Paul',
#    'xlm_oneshot_1beam': 'Paul and Bob. Context: Dennis is not a programmer, but Lisa',
#    'xlm_zeroshot_1beam': ' Robert is a lawyer.',
#    'xlm_zeroshot_2beam': ' Robert is a lawyer, but Paul and Bob are lawyers.'}},
#  '27': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not a lawyer, but Sophia and Charlotte are. ',
#   'question': 'Who are lawyers? ',
#   'answer': 'Sophia and Charlotte.',
#   'prompt': 'Context: Mary is not a lawyer, but Sophia and Charlotte are.  Question: Who are lawyers?  Answer:',
#   'targets': {'N1': 'mary',
#    'P2': 'lawyer',
#    'P1A': 'sophia',
#    'P1B': 'charlotte'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Mary. Context: Mary. Context: Mary. Context:',
#    'xglm_oneshot_altex_2beam': ' Mary. Context: Mary. Context: Mary. Context:',
#    'xlm_oneshot_1beam': 'Sophia. Context: Mary is not a lawyer, but Sophia and Charlotte',
#    'xlm_zeroshot_1beam': ' Mary is a lawyer.',
#    'xlm_zeroshot_2beam': ' Mary is not a lawyer, but Sophia and Charlotte are.'}},
#  '28': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not an actress, but Christopher and Charles are. ',
#   'question': 'Who are actors? ',
#   'answer': 'Christopher and Charles.',
#   'prompt': 'Context: Mary is not an actress, but Christopher and Charles are.  Question: Who are actors?  Answer:',
#   'targets': {'N1': 'mary',
#    'P2': 'actress',
#    'P1A': 'christopher',
#    'P1B': 'charles'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Christopher and Charles. Context: Dennis is not a programmer, but Lisa',
#    'xglm_oneshot_altex_2beam': ' Christopher and Charles. Context: Dennis is not a programmer, but Lisa',
#    'xlm_oneshot_1beam': 'Christopher and Charles. Context: Dennis is not a programmer, but Lisa',
#    'xlm_zeroshot_1beam': ' Mary is a.',
#    'xlm_zeroshot_2beam': ' Christopher and Charles are actors, but Mary is not an actress.'}},
#  '29': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Kirk is not a farmer, but Emma and Monica are. ',
#   'question': 'Who are farmers? ',
#   'answer': 'Emma and Monica.',
#   'prompt': 'Context: Kirk is not a farmer, but Emma and Monica are.  Question: Who are farmers?  Answer:',
#   'targets': {'N1': 'kirk', 'P2': 'farmer', 'P1A': 'emma', 'P1B': 'monica'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Kirk. Context: Kirk is not a farmer, but Emma and Monica',
#    'xglm_oneshot_altex_2beam': ' Kirk. Context: Kirk is not a farmer, but Emma and Monica',
#    'xlm_oneshot_1beam': 'Kirk. Context: Kirk is not a farmer, but Emma and Monica',
#    'xlm_zeroshot_1beam': ' Kirk is a farmer.',
#    'xlm_zeroshot_2beam': ' Kirk is a farmer.'}},
#  '30': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Steve is not a scientist, but Alice and Harper are. ',
#   'question': 'Who are scientists? ',
#   'answer': 'Alice and Harper.',
#   'prompt': 'Context: Steve is not a scientist, but Alice and Harper are.  Question: Who are scientists?  Answer:',
#   'targets': {'N1': 'steve',
#    'P2': 'scientist',
#    'P1A': 'alice',
#    'P1B': 'harper'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Steve. Context: Alice. Context: Harper. Context:',
#    'xglm_oneshot_altex_2beam': ' Steve. Context: Alice and Harper. Question: Who is not a',
#    'xlm_oneshot_1beam': 'Alice. Context: Steve is not a scientist, but Alice and Harper',
#    'xlm_zeroshot_1beam': ' Steve is a scientist.',
#    'xlm_zeroshot_2beam': ' Steve is not a scientist, but Alice and Harper are.'}},
#  '31': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not a waitress, but John is. ',
#   'question': 'Who is a waiter? ',
#   'answer': 'John.',
#   'prompt': 'Context: Mary is not a waitress, but John is.  Question: Who is a waiter?  Answer:',
#   'targets': {'N1': 'mary', 'P2': 'waitress', 'P1': 'john'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' John. Context: Mary is a waitress, but John is',
#    'xglm_oneshot_altex_2beam': ' John. Context: Mary is not a waitress, but John',
#    'xlm_oneshot_1beam': 'John. Context: Mary is not a waitress, but John',
#    'xlm_zeroshot_1beam': ' Mary is a waitress.',
#    'xlm_zeroshot_2beam': ' Mary is a waitress, but John is a waiter.'}},
#  '32': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Rachel is not an engineer, but Alice and Harper are. ',
#   'question': 'Who are engineers? ',
#   'answer': 'Alice and Harper.',
#   'prompt': 'Context: Rachel is not an engineer, but Alice and Harper are.  Question: Who are engineers?  Answer:',
#   'targets': {'N1': 'rachel',
#    'P2': 'engineer',
#    'P1A': 'alice',
#    'P1B': 'harper'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Rachel. Context: Rachel. Context: Rachel. Context:',
#    'xglm_oneshot_altex_2beam': ' Rachel. Context: Rachel. Context: Rachel. Context:',
#    'xlm_oneshot_1beam': 'Alice. Context: Rachel. Context: Alice. Context:',
#    'xlm_zeroshot_1beam': ' Rachel is an engineer.',
#    'xlm_zeroshot_2beam': ' Rachel is an engineer, but Alice and Harper are engineers.'}},
#  '33': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lily is not a policewoman, but Steve is. ',
#   'question': 'Who is a policeman? ',
#   'answer': 'Steve.',
#   'prompt': 'Context: Lily is not a policewoman, but Steve is.  Question: Who is a policeman?  Answer:',
#   'targets': {'N1': 'lily', 'P2': 'policewoman', 'P1': 'steve'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Steve. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Steve. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_oneshot_1beam': 'Steve. Context: Lisa is not a policewoman, but Steve is',
#    'xlm_zeroshot_1beam': ' Lily is a policewoman.',
#    'xlm_zeroshot_2beam': ' Lily is a policewoman, but Steve is a policeman.'}},
#  '34': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lola is not an actress, but Joseph and Thomas are. ',
#   'question': 'Who are actors? ',
#   'answer': 'Joseph and Thomas.',
#   'prompt': 'Context: Lola is not an actress, but Joseph and Thomas are.  Question: Who are actors?  Answer:',
#   'targets': {'N1': 'lola', 'P2': 'actress', 'P1A': 'joseph', 'P1B': 'thomas'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Joseph and Thomas. Context: Dennis is not a programmer, but Lisa',
#    'xglm_oneshot_altex_2beam': ' Dennis. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_oneshot_1beam': 'Joseph and Thomas. Context: Joseph and Thomas. Context: Joseph',
#    'xlm_zeroshot_1beam': ' Lola is a.',
#    'xlm_zeroshot_2beam': ' Joseph and Thomas are actors. Question: Who are actors? Answer: Joseph'}},
#  '35': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Susan is not a lawyer, but Robert is. ',
#   'question': 'Who is a lawyer? ',
#   'answer': 'Robert.',
#   'prompt': 'Context: Susan is not a lawyer, but Robert is.  Question: Who is a lawyer?  Answer:',
#   'targets': {'N1': 'susan', 'P2': 'lawyer', 'P1': 'robert'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Robert. Context: Susan is not a lawyer, but Robert is.',
#    'xglm_oneshot_altex_2beam': ' Robert. Context: Susan is not a lawyer, but Robert is.',
#    'xlm_oneshot_1beam': 'Robert. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Susan is a lawyer.',
#    'xlm_zeroshot_2beam': ' Susan is not a lawyer, but Robert is.'}},
#  '36': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Rachel is not a policewoman, but Lily is. ',
#   'question': 'Who is a policeman? ',
#   'answer': 'Lily.',
#   'prompt': 'Context: Rachel is not a policewoman, but Lily is.  Question: Who is a policeman?  Answer:',
#   'targets': {'N1': 'rachel', 'P2': 'policewoman', 'P1': 'lily'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Rachel. Context: Rachel. Context: Rachel. Context:',
#    'xglm_oneshot_altex_2beam': ' Rachel. Context: Lisa is not a policewoman, but Lily is',
#    'xlm_oneshot_1beam': 'Lily. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Rachel is a policewoman.',
#    'xlm_zeroshot_2beam': ' Rachel is a policewoman, and Lily is a policewoman.'}},
#  '37': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Eleanor and Lillian are not lawyers, but Joseph and Thomas are. ',
#   'question': 'Who are lawyers? ',
#   'answer': 'Joseph and Thomas.',
#   'prompt': 'Context: Eleanor and Lillian are not lawyers, but Joseph and Thomas are.  Question: Who are lawyers?  Answer:',
#   'targets': {'N1A': 'eleanor',
#    'N1B': 'lillian',
#    'P2': 'lawyers',
#    'P1A': 'joseph',
#    'P1B': 'thomas'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Joseph. Context: Joseph. Context: Joseph. Context:',
#    'xglm_oneshot_altex_2beam': ' Joseph. Context: Joseph. Context: Joseph. Context:',
#    'xlm_oneshot_1beam': 'Joseph and Thomas. Context: Joseph and Thomas are not lawyers, but',
#    'xlm_zeroshot_1beam': ' Joseph and Thomas are lawyers.',
#    'xlm_zeroshot_2beam': ' Eleanor and Lillian are not lawyers, but Joseph and Thomas are.'}},
#  '38': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lily is not a teacher, but Ross and Joey are. ',
#   'question': 'Who are teachers? ',
#   'answer': 'Ross and Joey.',
#   'prompt': 'Context: Lily is not a teacher, but Ross and Joey are.  Question: Who are teachers?  Answer:',
#   'targets': {'N1': 'lily', 'P2': 'teacher', 'P1A': 'ross', 'P1B': 'joey'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Lily. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Ross and Joey. Context: Dennis is not a programmer, but',
#    'xlm_oneshot_1beam': 'Ross and Joey.',
#    'xlm_zeroshot_1beam': ' Lily is a teacher.',
#    'xlm_zeroshot_2beam': ' Lily is not a teacher, but Ross and Joey are.'}},
#  '39': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lola is not a scientist, but Clark is. ',
#   'question': 'Who is a scientist? ',
#   'answer': 'Clark.',
#   'prompt': 'Context: Lola is not a scientist, but Clark is.  Question: Who is a scientist?  Answer:',
#   'targets': {'N1': 'lola', 'P2': 'scientist', 'P1': 'clark'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Clark. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Clark. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_oneshot_1beam': 'Clark. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Clark is a scientist.',
#    'xlm_zeroshot_2beam': ' A scientist is a person who is interested in science. A scientist is a'}},
#  '40': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Susan is not a doctor, but Kirk is. ',
#   'question': 'Who is a doctor? ',
#   'answer': 'Kirk.',
#   'prompt': 'Context: Susan is not a doctor, but Kirk is.  Question: Who is a doctor?  Answer:',
#   'targets': {'N1': 'susan', 'P2': 'doctor', 'P1': 'kirk'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Kirk. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Kirk. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_oneshot_1beam': 'Kirk. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Susan is a doctor.',
#    'xlm_zeroshot_2beam': ' Susan is not a doctor, but Kirk is.'}},
#  '41': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not a farmer, but Steve is. ',
#   'question': 'Who is a farmer? ',
#   'answer': 'Steve.',
#   'prompt': 'Context: Mary is not a farmer, but Steve is.  Question: Who is a farmer?  Answer:',
#   'targets': {'N1': 'mary', 'P2': 'farmer', 'P1': 'steve'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Steve. Context: Mary. Context: Steve. Context:',
#    'xglm_oneshot_altex_2beam': ' Steve. Context: Mary is not a farmer, but Steve is.',
#    'xlm_oneshot_1beam': 'Steve. Context: Mary is not a farmer, but Steve is.',
#    'xlm_zeroshot_1beam': ' Mary is a farmer.',
#    'xlm_zeroshot_2beam': ' Mary is a farmer.'}},
#  '42': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Steve is not an architect, but Ross and Joey are. ',
#   'question': 'Who are architects? ',
#   'answer': 'Ross and Joey.',
#   'prompt': 'Context: Steve is not an architect, but Ross and Joey are.  Question: Who are architects?  Answer:',
#   'targets': {'N1': 'steve', 'P2': 'architect', 'P1A': 'ross', 'P1B': 'joey'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Steve. Context: Steve. Context: Steve. Context:',
#    'xglm_oneshot_altex_2beam': ' Steve. Context: Steve. Context: Steve. Context:',
#    'xlm_oneshot_1beam': 'Ross and Joey. Context: Steve is not an architect, but',
#    'xlm_zeroshot_1beam': ' Steve is an architect.',
#    'xlm_zeroshot_2beam': ' Steve is an architect, but Ross and Joey are architects.'}},
#  '43': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not a scientist, but Ross and Joey are. ',
#   'question': 'Who are scientists? ',
#   'answer': 'Ross and Joey.',
#   'prompt': 'Context: Mary is not a scientist, but Ross and Joey are.  Question: Who are scientists?  Answer:',
#   'targets': {'N1': 'mary', 'P2': 'scientist', 'P1A': 'ross', 'P1B': 'joey'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Mary. Context: Mary. Context: Ross and Joey.',
#    'xglm_oneshot_altex_2beam': ' Ross and Joey. Context: Dennis is not a programmer, but',
#    'xlm_oneshot_1beam': 'Ross and Joey.',
#    'xlm_zeroshot_1beam': ' Mary is a scientist.',
#    'xlm_zeroshot_2beam': ' Ross and Joey are scientists.'}},
#  '44': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not a singer, but Ross and Joey are. ',
#   'question': 'Who are singers? ',
#   'answer': 'Ross and Joey.',
#   'prompt': 'Context: Mary is not a singer, but Ross and Joey are.  Question: Who are singers?  Answer:',
#   'targets': {'N1': 'mary', 'P2': 'singer', 'P1A': 'ross', 'P1B': 'joey'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Ross and Joey. Context: Dennis is not a programmer, but',
# ...
#  '986': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Sophia and Charlotte are accountants, Christopher and Charles are architects. ',
#   'question': 'Who are not accountants? ',
#   'answer': 'Christopher and Charles.',
#   'prompt': 'Context: Sophia and Charlotte are accountants, Christopher and Charles are architects.  Question: Who are not accountants?  Answer:',
#   'targets': {'N1A': 'sophia',
#    'N1B': 'charlotte',
#    'N2': 'accountants',
#    'P1A': 'christopher',
#    'P1B': 'charles',
#    'P2': 'architects'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Christopher. Context: Charles. Context: Charles. Context:',
#    'xglm_oneshot_altex_2beam': ' Christopher. Context: Charles. Context: Charles. Context:',
#    'xlm_oneshot_1beam': 'Charles. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xlm_zeroshot_1beam': ' They are not accountants.',
#    'xlm_zeroshot_2beam': ' They are not architects. Question: Who are not accountants? Answer'}},
#  '987': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Steve is an actor, Emma and Monica are cooks. ',
#   'question': 'Who are not actors? ',
#   'answer': 'Emma and Monica.',
#   'prompt': 'Context: Steve is an actor, Emma and Monica are cooks.  Question: Who are not actors?  Answer:',
#   'targets': {'N1': 'steve',
#    'N2': 'actor',
#    'P1A': 'emma',
#    'P1B': 'monica',
#    'P2': 'cooks'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Emma. Context: Steve is a musician. Question: Who are not',
#    'xglm_oneshot_altex_2beam': ' Emma. Context: Monica is a singer. Question: Who are not',
#    'xlm_oneshot_1beam': 'Emma. Context: Monica is a singer. Question: Who are not',
#    'xlm_zeroshot_1beam': ' Emma is a singer, Monica is a model, and Steve is a musician',
#    'xlm_zeroshot_2beam': ' Steve is an actor, Emma and Monica are cooks.'}},
#  '988': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Robert is an actor, Emma and Monica are lawyers. ',
#   'question': 'Who are not actors? ',
#   'answer': 'Emma and Monica.',
#   'prompt': 'Context: Robert is an actor, Emma and Monica are lawyers.  Question: Who are not actors?  Answer:',
#   'targets': {'N1': 'robert',
#    'N2': 'actor',
#    'P1A': 'emma',
#    'P1B': 'monica',
#    'P2': 'lawyers'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Monica. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xglm_oneshot_altex_2beam': ' Monica. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xlm_oneshot_1beam': 'Monica. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xlm_zeroshot_1beam': ' Robert is an actor, Emma and Monica are lawyers.',
#    'xlm_zeroshot_2beam': ' Robert is an actor, Emma and Monica are lawyers.'}},
#  '989': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Alice and Harper are engineers, Ross and Joey are teachers. ',
#   'question': 'Who are not engineers? ',
#   'answer': 'Ross and Joey.',
#   'prompt': 'Context: Alice and Harper are engineers, Ross and Joey are teachers.  Question: Who are not engineers?  Answer:',
#   'targets': {'N1A': 'alice',
#    'N1B': 'harper',
#    'N2': 'engineers',
#    'P1A': 'ross',
#    'P1B': 'joey',
#    'P2': 'teachers'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Ross. Context: Alice and Harper are engineers. Question: Who are',
#    'xglm_oneshot_altex_2beam': ' Ross and Joey. Context: Dennis is a programmer, Lisa is',
#    'xlm_oneshot_1beam': 'Ross and Joey. Context: Dennis is a programmer, Lisa is',
#    'xlm_zeroshot_1beam': ' They are engineers.',
#    'xlm_zeroshot_2beam': ' They are engineers, Ross and Joey are teachers, and Alice and Harper'}},
#  '990': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Kirk is a teacher, James is a policeman. ',
#   'question': 'Who is not a teacher? ',
#   'answer': 'James.',
#   'prompt': 'Context: Kirk is a teacher, James is a policeman.  Question: Who is not a teacher?  Answer:',
#   'targets': {'N1': 'kirk', 'N2': 'teacher', 'P1': 'james', 'P2': 'policeman'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' James. Context: Kirk is a policeman. Question: Who is',
#    'xglm_oneshot_altex_2beam': ' James. Context: Kirk is a teacher, James is a policeman',
#    'xlm_oneshot_1beam': 'James. Context: Kirk is a teacher, James is a policeman',
#    'xlm_zeroshot_1beam': ' James is a policeman.',
#    'xlm_zeroshot_2beam': ' James is a policeman.'}},
#  '991': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Robert is a teacher, Sophia and Charlotte are policewomen. ',
#   'question': 'Who are not teachers? ',
#   'answer': 'Sophia and Charlotte.',
#   'prompt': 'Context: Robert is a teacher, Sophia and Charlotte are policewomen.  Question: Who are not teachers?  Answer:',
#   'targets': {'N1': 'robert',
#    'N2': 'teacher',
#    'P1A': 'sophia',
#    'P1B': 'charlotte',
#    'P2': 'policewomen'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Robert. Context: Robert is a teacher. Question: Who are not',
#    'xglm_oneshot_altex_2beam': ' Robert. Context: Dennis is a teacher, Sophia and Charlotte are police',
#    'xlm_oneshot_1beam': 'Sophia and Charlotte. Context: Dennis is a programmer, Lisa is a',
#    'xlm_zeroshot_1beam': ' Robert is a teacher, Sophia and Charlotte are policewomen.',
#    'xlm_zeroshot_2beam': ' Robert is a teacher, Sophia and Charlotte are policewomen.'}},
#  '992': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Susan is a scientist, Audrey is an accountant. ',
#   'question': 'Who is not a scientist? ',
#   'answer': 'Audrey.',
#   'prompt': 'Context: Susan is a scientist, Audrey is an accountant.  Question: Who is not a scientist?  Answer:',
#   'targets': {'N1': 'susan',
#    'N2': 'scientist',
#    'P1': 'audrey',
#    'P2': 'accountant'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Susan. Context: Susan is a scientist. Question: Who is not',
#    'xglm_oneshot_altex_2beam': ' Susan. Context: Susan is a scientist. Question: Who is not',
#    'xlm_oneshot_1beam': 'Audrey. Context: Susan is a scientist, Audrey is an',
#    'xlm_zeroshot_1beam': ' Susan is a scientist.',
#    'xlm_zeroshot_2beam': ' Susan is a scientist, Audrey is an accountant.'}},
#  '993': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Audrey is a policewoman, Mark and Andrew are lawyers. ',
#   'question': 'Who are not policemen? ',
#   'answer': 'Mark and Andrew.',
#   'prompt': 'Context: Audrey is a policewoman, Mark and Andrew are lawyers.  Question: Who are not policemen?  Answer:',
#   'targets': {'N1': 'audrey',
#    'N2': 'policewoman',
#    'P1A': 'mark',
#    'P1B': 'andrew',
#    'P2': 'lawyers'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Mark. Context: Mark. Context: Mark. Context:',
#    'xglm_oneshot_altex_2beam': ' Mark. Context: Mark. Context: Mark. Context:',
#    'xlm_oneshot_1beam': 'Mark. Context: Mark and Andrew. Question: Who is not a',
#    'xlm_zeroshot_1beam': ' Mark is a policeman. Mark is a lawyer. Mark is a lawyer',
#    'xlm_zeroshot_2beam': ' Mark is a policeman. Mark is a lawyer. Mark is a lawyer'}},
#  '994': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is a singer, Lola is a doctor. ',
#   'question': 'Who is not a singer? ',
#   'answer': 'Lola.',
#   'prompt': 'Context: Mary is a singer, Lola is a doctor.  Question: Who is not a singer?  Answer:',
#   'targets': {'N1': 'mary', 'N2': 'singer', 'P1': 'lola', 'P2': 'doctor'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Lola. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xglm_oneshot_altex_2beam': ' Lola. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xlm_oneshot_1beam': 'Lola. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xlm_zeroshot_1beam': ' Mary is a singer.',
#    'xlm_zeroshot_2beam': ' Mary is a singer.'}},
#  '995': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Steve is a singer, Mark and Andrew are architects. ',
#   'question': 'Who are not singers? ',
#   'answer': 'Mark and Andrew.',
#   'prompt': 'Context: Steve is a singer, Mark and Andrew are architects.  Question: Who are not singers?  Answer:',
#   'targets': {'N1': 'steve',
#    'N2': 'singer',
#    'P1A': 'mark',
#    'P1B': 'andrew',
#    'P2': 'architects'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Mark. Context: Mark. Context: Mark. Context:',
#    'xglm_oneshot_altex_2beam': ' Mark. Context: Mark. Context: Mark. Context:',
#    'xlm_oneshot_1beam': 'Mark. Context: Mark. Context: Mark. Context:',
#    'xlm_zeroshot_1beam': ' Steve is a singer, Mark and Andrew are architects.',
#    'xlm_zeroshot_2beam': ' Steve is a singer, Mark and Andrew are architects.'}},
#  '996': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lily is a waitress, Mark and Andrew are policemen. ',
#   'question': 'Who are not waiters? ',
#   'answer': 'Mark and Andrew.',
#   'prompt': 'Context: Lily is a waitress, Mark and Andrew are policemen.  Question: Who are not waiters?  Answer:',
#   'targets': {'N1': 'lily',
#    'N2': 'waitress',
#    'P1A': 'mark',
#    'P1B': 'andrew',
#    'P2': 'policemen'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Mark. Context: Mark. Context: Mark. Context:',
#    'xglm_oneshot_altex_2beam': ' Mark. Context: Mark. Context: Mark. Context:',
#    'xlm_oneshot_1beam': 'Mark. Context: Mark. Context: Mark. Context:',
#    'xlm_zeroshot_1beam': ' Mark is a waitress. Question: What is the difference between a',
#    'xlm_zeroshot_2beam': ' Mark is a waitress, Andrew is a policeman.'}},
#  '997': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Susan is a teacher, Sophia and Charlotte are managers. ',
#   'question': 'Who are not teachers? ',
#   'answer': 'Sophia and Charlotte.',
#   'prompt': 'Context: Susan is a teacher, Sophia and Charlotte are managers.  Question: Who are not teachers?  Answer:',
#   'targets': {'N1': 'susan',
#    'N2': 'teacher',
#    'P1A': 'sophia',
#    'P1B': 'charlotte',
#    'P2': 'managers'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Susan. Context: Susan. Context: Susan. Context:',
#    'xglm_oneshot_altex_2beam': ' Susan. Context: Susan. Context: Susan. Context:',
#    'xlm_oneshot_1beam': 'Sophia. Context: Susan. Context: Sophia. Context:',
#    'xlm_zeroshot_1beam': ' Susan is a teacher, Sophia and Charlotte are managers.',
#    'xlm_zeroshot_2beam': ' Susan is a teacher, Sophia and Charlotte are managers.'}},
#  '998': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Audrey is a singer, Lily is a manager. ',
#   'question': 'Who is not a singer? ',
#   'answer': 'Lily.',
#   'prompt': 'Context: Audrey is a singer, Lily is a manager.  Question: Who is not a singer?  Answer:',
#   'targets': {'N1': 'audrey', 'N2': 'singer', 'P1': 'lily', 'P2': 'manager'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Lily. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xglm_oneshot_altex_2beam': ' Lily. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xlm_oneshot_1beam': 'Lily. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xlm_zeroshot_1beam': ' Audrey is a singer.',
#    'xlm_zeroshot_2beam': ' Audrey is a singer, Lily is a manager.'}},
#  '999': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is a writer, Audrey is a doctor. ',
#   'question': 'Who is not a writer? ',
#   'answer': 'Audrey.',
#   'prompt': 'Context: Mary is a writer, Audrey is a doctor.  Question: Who is not a writer?  Answer:',
#   'targets': {'N1': 'mary', 'N2': 'writer', 'P1': 'audrey', 'P2': 'doctor'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Audrey. Context: Mary is a writer. Question: Who is',
#    'xglm_oneshot_altex_2beam': ' Audrey. Context: Dennis is a programmer, Lisa is a therapist',
#    'xlm_oneshot_1beam': 'Audrey. Context: Mary is a writer, Audrey is a',
#    'xlm_zeroshot_1beam': ' Mary is a writer.',
#    'xlm_zeroshot_2beam': ' Audrey is a doctor, Mary is a writer, Audrey is a'}},
#  ...}

# %%
for id, item in data.items():
    item['response']["xlm_oneshot_2beam"] = item['response']["xlm_oneshot_1beam"]
    del item['response']["xlm_oneshot_1beam"]

# %%
data
# Out:
# {'0': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Susan is not an architect, but Lola is. ',
#   'question': 'Who is an architect? ',
#   'answer': 'Lola.',
#   'prompt': 'Context: Susan is not an architect, but Lola is.  Question: Who is an architect?  Answer:',
#   'targets': {'N1': 'susan', 'P2': 'architect', 'P1': 'lola'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Susan. Context: Susan is not an architect.',
#    'xglm_oneshot_altex_2beam': ' Susan. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Susan is an architect.',
#    'xlm_zeroshot_2beam': ' Susan is an architect, Lola is an architect, and Susan is an architect',
#    'xlm_oneshot_2beam': 'Lola. Context: Dennis is not a programmer, but Lisa is.'}},
#  '1': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'John is not a lawyer, but Sophia and Charlotte are. ',
#   'question': 'Who are lawyers? ',
#   'answer': 'Sophia and Charlotte.',
#   'prompt': 'Context: John is not a lawyer, but Sophia and Charlotte are.  Question: Who are lawyers?  Answer:',
#   'targets': {'N1': 'john',
#    'P2': 'lawyer',
#    'P1A': 'sophia',
#    'P1B': 'charlotte'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' John. Context: John is not a lawyer, but Sophia and Charlotte',
#    'xglm_oneshot_altex_2beam': ' John. Context: John is not a lawyer, but Sophia and Charlotte',
#    'xlm_zeroshot_1beam': ' John is a lawyer.',
#    'xlm_zeroshot_2beam': ' John is not a lawyer, but Sophia and Charlotte are.',
#    'xlm_oneshot_2beam': 'Sophia. Context: John is not a lawyer, but Sophia and Charlotte'}},
#  '2': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Kirk is not a scientist, but Robert is. ',
#   'question': 'Who is a scientist? ',
#   'answer': 'Robert.',
#   'prompt': 'Context: Kirk is not a scientist, but Robert is.  Question: Who is a scientist?  Answer:',
#   'targets': {'N1': 'kirk', 'P2': 'scientist', 'P1': 'robert'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Kirk. Context: Kirk is not a scientist, but Robert is.',
#    'xglm_oneshot_altex_2beam': ' Kirk. Context: Kirk is not a scientist, but Robert is.',
#    'xlm_zeroshot_1beam': ' Robert Kirk is a scientist.',
#    'xlm_zeroshot_2beam': ' Robert Kirk is a scientist.',
#    'xlm_oneshot_2beam': 'Robert. Context: Kirk is not a scientist, but Robert is.'}},
#  '3': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not a farmer, but Lily is. ',
#   'question': 'Who is a farmer? ',
#   'answer': 'Lily.',
#   'prompt': 'Context: Mary is not a farmer, but Lily is.  Question: Who is a farmer?  Answer:',
#   'targets': {'N1': 'mary', 'P2': 'farmer', 'P1': 'lily'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Mary. Context: Lily is not a farmer, but Lily is.',
#    'xglm_oneshot_altex_2beam': ' Lily. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Mary is a farmer.',
#    'xlm_zeroshot_2beam': ' Mary is a farmer, and Lily is a farmer.',
#    'xlm_oneshot_2beam': 'Lily. Context: Dennis is not a programmer, but Lisa is.'}},
#  '4': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'James is not a writer, but Paul and Bob are. ',
#   'question': 'Who are writers? ',
#   'answer': 'Paul and Bob.',
#   'prompt': 'Context: James is not a writer, but Paul and Bob are.  Question: Who are writers?  Answer:',
#   'targets': {'N1': 'james', 'P2': 'writer', 'P1A': 'paul', 'P1B': 'bob'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' James. Context: Paul and Bob.',
#    'xglm_oneshot_altex_2beam': ' Paul and Bob. Context: Dennis is not a programmer, but Lisa',
#    'xlm_zeroshot_1beam': ' James is a writer.',
#    'xlm_zeroshot_2beam': ' James is a writer, but Paul and Bob are writers.',
#    'xlm_oneshot_2beam': 'Paul and Bob. Context: Paul and Bob. Context: Paul'}},
#  '5': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Audrey is not a doctor, but Olivia and Emily are. ',
#   'question': 'Who are doctors? ',
#   'answer': 'Olivia and Emily.',
#   'prompt': 'Context: Audrey is not a doctor, but Olivia and Emily are.  Question: Who are doctors?  Answer:',
#   'targets': {'N1': 'audrey', 'P2': 'doctor', 'P1A': 'olivia', 'P1B': 'emily'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Audrey. Context: Audrey is not a doctor, but Olivia',
#    'xglm_oneshot_altex_2beam': ' Audrey. Context: Audrey is not a doctor, but Olivia',
#    'xlm_zeroshot_1beam': ' Audrey is a doctor. Emily is a nurse.',
#    'xlm_zeroshot_2beam': ' Audrey is not a doctor, but Olivia and Emily are.',
#    'xlm_oneshot_2beam': 'Audrey. Context: Audrey is not a doctor, but Olivia'}},
#  '6': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'James is not a farmer, but Eleanor and Lillian are. ',
#   'question': 'Who are farmers? ',
#   'answer': 'Eleanor and Lillian.',
#   'prompt': 'Context: James is not a farmer, but Eleanor and Lillian are.  Question: Who are farmers?  Answer:',
#   'targets': {'N1': 'james',
#    'P2': 'farmer',
#    'P1A': 'eleanor',
#    'P1B': 'lillian'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' James. Context: James is not a farmer, but Eleanor and',
#    'xglm_oneshot_altex_2beam': ' James. Context: James is not a farmer, but Eleanor and',
#    'xlm_zeroshot_1beam': ' James is a farmer.',
#    'xlm_zeroshot_2beam': ' James is a farmer. Eleanor and Lillian are farmers.',
#    'xlm_oneshot_2beam': 'Eleanor. Context: James is not a farmer, but Eleanor'}},
#  '7': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Audrey is not a waitress, but Eleanor and Lillian are. ',
#   'question': 'Who are waiters? ',
#   'answer': 'Eleanor and Lillian.',
#   'prompt': 'Context: Audrey is not a waitress, but Eleanor and Lillian are.  Question: Who are waiters?  Answer:',
#   'targets': {'N1': 'audrey',
#    'P2': 'waitress',
#    'P1A': 'eleanor',
#    'P1B': 'lillian'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Audrey. Context: Audrey is a waitress, but',
#    'xglm_oneshot_altex_2beam': ' Audrey. Context: Audrey is not a waitress,',
#    'xlm_zeroshot_1beam': ' Audrey is a waitress.',
#    'xlm_zeroshot_2beam': ' Audrey is a waitress, and Lillian is a waitres',
#    'xlm_oneshot_2beam': 'Eleanor. Context: Audrey is not a waitress,'}},
#  '8': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Emma and Monica are not writers, but Eleanor and Lillian are. ',
#   'question': 'Who are writers? ',
#   'answer': 'Eleanor and Lillian.',
#   'prompt': 'Context: Emma and Monica are not writers, but Eleanor and Lillian are.  Question: Who are writers?  Answer:',
#   'targets': {'N1A': 'emma',
#    'N1B': 'monica',
#    'P2': 'writers',
#    'P1A': 'eleanor',
#    'P1B': 'lillian'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Eleanor. Context: Dennis is not a programmer, but Lisa is',
#    'xglm_oneshot_altex_2beam': ' Eleanor. Context: Dennis is not a programmer, but Lisa is',
#    'xlm_zeroshot_1beam': ' Emma and Monica are not writers, but Eleanor and Lillian are.',
#    'xlm_zeroshot_2beam': ' Emma and Monica are not writers, but Eleanor and Lillian are.',
#    'xlm_oneshot_2beam': 'Eleanor and Lillian.'}},
#  '9': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lily is not a waitress, but Steve is. ',
#   'question': 'Who is a waiter? ',
#   'answer': 'Steve.',
#   'prompt': 'Context: Lily is not a waitress, but Steve is.  Question: Who is a waiter?  Answer:',
#   'targets': {'N1': 'lily', 'P2': 'waitress', 'P1': 'steve'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Steve. Context: Dennis is not a waiter, but Lisa is',
#    'xglm_oneshot_altex_2beam': ' Steve. Context: Lisa is not a waitress, but Lisa',
#    'xlm_zeroshot_1beam': ' Lily is a waitress.',
#    'xlm_zeroshot_2beam': ' Lily is a waitress, but Steve is a waiter.',
#    'xlm_oneshot_2beam': 'Steve. Context: Steve. Context: Steve. Context:'}},
#  '10': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Robert is not a lawyer, but Mark and Andrew are. ',
#   'question': 'Who are lawyers? ',
#   'answer': 'Mark and Andrew.',
#   'prompt': 'Context: Robert is not a lawyer, but Mark and Andrew are.  Question: Who are lawyers?  Answer:',
#   'targets': {'N1': 'robert', 'P2': 'lawyer', 'P1A': 'mark', 'P1B': 'andrew'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Robert. Context: Mark. Context: Andrew. Context:',
#    'xglm_oneshot_altex_2beam': ' Robert. Context: Mark. Context: Andrew. Context:',
#    'xlm_zeroshot_1beam': ' Robert is a lawyer. Mark is a lawyer. Mark is a lawyer.',
#    'xlm_zeroshot_2beam': ' Robert is a lawyer. Mark is a lawyer. Mark is a lawyer.',
#    'xlm_oneshot_2beam': 'Mark. Context: Mark. Context: Mark. Context:'}},
#  '11': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Audrey is not an actress, but Alice and Harper are. ',
#   'question': 'Who are actors? ',
#   'answer': 'Alice and Harper.',
#   'prompt': 'Context: Audrey is not an actress, but Alice and Harper are.  Question: Who are actors?  Answer:',
#   'targets': {'N1': 'audrey',
#    'P2': 'actress',
#    'P1A': 'alice',
#    'P1B': 'harper'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Audrey. Context: Audrey is not a singer, but Alice',
#    'xglm_oneshot_altex_2beam': ' Audrey. Context: Audrey is not an actress, but Alice',
#    'xlm_zeroshot_1beam': ' Audrey is an actress, but Alice and Harper are.',
#    'xlm_zeroshot_2beam': ' Audrey is an actress, but Alice and Harper are actors.',
#    'xlm_oneshot_2beam': 'Audrey. Context: Audrey is not an actress, but Alice'}},
#  '12': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lily is not an accountant, but Joseph and Thomas are. ',
#   'question': 'Who are accountants? ',
#   'answer': 'Joseph and Thomas.',
#   'prompt': 'Context: Lily is not an accountant, but Joseph and Thomas are.  Question: Who are accountants?  Answer:',
#   'targets': {'N1': 'lily',
#    'P2': 'accountant',
#    'P1A': 'joseph',
#    'P1B': 'thomas'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Joseph. Context: Thomas. Context: Joseph. Context:',
#    'xglm_oneshot_altex_2beam': ' Joseph. Context: Thomas. Context: Joseph. Context:',
#    'xlm_zeroshot_1beam': ' Joseph is a lawyer. Question: Who are accountants? Answer: Thomas',
#    'xlm_zeroshot_2beam': ' Accountants are accountants.',
#    'xlm_oneshot_2beam': 'Joseph and Thomas. Context: Joseph and Thomas. Context: Joseph'}},
#  '13': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Rachel is not a writer, but Steve is. ',
#   'question': 'Who is a writer? ',
#   'answer': 'Steve.',
#   'prompt': 'Context: Rachel is not a writer, but Steve is.  Question: Who is a writer?  Answer:',
#   'targets': {'N1': 'rachel', 'P2': 'writer', 'P1': 'steve'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Steve. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Steve. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Rachel is a writer.',
#    'xlm_zeroshot_2beam': ' Rachel is a writer, but Steve is a writer.',
#    'xlm_oneshot_2beam': 'Steve. Context: Lisa is not a programmer, but Lisa is.'}},
#  '14': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'John is not a scientist, but Paul and Bob are. ',
#   'question': 'Who are scientists? ',
#   'answer': 'Paul and Bob.',
#   'prompt': 'Context: John is not a scientist, but Paul and Bob are.  Question: Who are scientists?  Answer:',
#   'targets': {'N1': 'john', 'P2': 'scientist', 'P1A': 'paul', 'P1B': 'bob'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Paul and Bob. Context: Dennis is not a scientist, but Paul',
#    'xglm_oneshot_altex_2beam': ' Paul and Bob. Context: Dennis is not a programmer, but Lisa',
#    'xlm_zeroshot_1beam': ' John is a scientist.',
#    'xlm_zeroshot_2beam': ' John is a scientist, but Paul and Bob are scientists.',
#    'xlm_oneshot_2beam': 'Paul and Bob. Context: Paul and Bob. Context: Paul'}},
#  '15': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lily is not an actress, but Eleanor and Lillian are. ',
#   'question': 'Who are actors? ',
#   'answer': 'Eleanor and Lillian.',
#   'prompt': 'Context: Lily is not an actress, but Eleanor and Lillian are.  Question: Who are actors?  Answer:',
#   'targets': {'N1': 'lily',
#    'P2': 'actress',
#    'P1A': 'eleanor',
#    'P1B': 'lillian'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Dennis. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Dennis. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Lily is an actress.',
#    'xlm_zeroshot_2beam': ' Lily is an actress, but Eleanor and Lillian are actors.',
#    'xlm_oneshot_2beam': 'Lily. Context: Lily is not an actress, but Eleanor and'}},
#  '16': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lola is not a policewoman, but James is. ',
#   'question': 'Who is a policeman? ',
#   'answer': 'James.',
#   'prompt': 'Context: Lola is not a policewoman, but James is.  Question: Who is a policeman?  Answer:',
#   'targets': {'N1': 'lola', 'P2': 'policewoman', 'P1': 'james'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' James. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' James. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' James is a policeman.',
#    'xlm_zeroshot_2beam': ' James is a policeman. Context: James is a policeman.',
#    'xlm_oneshot_2beam': 'James. Context: Dennis is not a programmer, but Lisa is.'}},
#  '17': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not a doctor, but Mark and Andrew are. ',
#   'question': 'Who are doctors? ',
#   'answer': 'Mark and Andrew.',
#   'prompt': 'Context: Mary is not a doctor, but Mark and Andrew are.  Question: Who are doctors?  Answer:',
#   'targets': {'N1': 'mary', 'P2': 'doctor', 'P1A': 'mark', 'P1B': 'andrew'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Mary. Context: Mark. Context: Andrew. Context:',
#    'xglm_oneshot_altex_2beam': ' Mary. Context: Mark. Context: Andrew. Context:',
#    'xlm_zeroshot_1beam': ' Mary is a doctor. Mark is a doctor. Andrew is a doctor.',
#    'xlm_zeroshot_2beam': ' Mary is not a doctor, but Mark and Andrew are.',
#    'xlm_oneshot_2beam': 'Mark. Context: Mark. Context: Mark. Context:'}},
#  '18': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Susan is not a teacher, but Steve is. ',
#   'question': 'Who is a teacher? ',
#   'answer': 'Steve.',
#   'prompt': 'Context: Susan is not a teacher, but Steve is.  Question: Who is a teacher?  Answer:',
#   'targets': {'N1': 'susan', 'P2': 'teacher', 'P1': 'steve'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Susan. Context: Steve is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Susan. Context: Steve is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Susan is a teacher.',
#    'xlm_zeroshot_2beam': ' Susan is a teacher. Steve is a teacher. Susan is a teacher.',
#    'xlm_oneshot_2beam': 'Steve. Context: Susan is not a teacher, but Steve is.'}},
#  '19': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lily is not an actress, but Ross and Joey are. ',
#   'question': 'Who are actors? ',
#   'answer': 'Ross and Joey.',
#   'prompt': 'Context: Lily is not an actress, but Ross and Joey are.  Question: Who are actors?  Answer:',
#   'targets': {'N1': 'lily', 'P2': 'actress', 'P1A': 'ross', 'P1B': 'joey'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Dennis. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Ross and Joey. Context: Dennis is not a programmer, but',
#    'xlm_zeroshot_1beam': ' Lily is an actress.',
#    'xlm_zeroshot_2beam': ' Ross and Joey are actors, but Lily is not an actress.',
#    'xlm_oneshot_2beam': 'Ross and Joey. Context: Ross and Joey. Context'}},
#  '20': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Olivia and Emily are not actresses, but Ross and Joey are. ',
#   'question': 'Who are actors? ',
#   'answer': 'Ross and Joey.',
#   'prompt': 'Context: Olivia and Emily are not actresses, but Ross and Joey are.  Question: Who are actors?  Answer:',
#   'targets': {'N1A': 'olivia',
#    'N1B': 'emily',
#    'P2': 'actresses',
#    'P1A': 'ross',
#    'P1B': 'joey'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Ross. Context: Ross and Joey are not actors.',
#    'xglm_oneshot_altex_2beam': ' Dennis. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Ross and Joey are actors.',
#    'xlm_zeroshot_2beam': ' Ross and Joey are actors, but Olivia and Emily are actresses.',
#    'xlm_oneshot_2beam': 'Ross and Joey. Context: Ross and Joey are not actors'}},
#  '21': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'John is not a policeman, but Joseph and Thomas are. ',
#   'question': 'Who are policemen? ',
#   'answer': 'Joseph and Thomas.',
#   'prompt': 'Context: John is not a policeman, but Joseph and Thomas are.  Question: Who are policemen?  Answer:',
#   'targets': {'N1': 'john',
#    'P2': 'policeman',
#    'P1A': 'joseph',
#    'P1B': 'thomas'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' John. Context: John is not a policeman, but Joseph and',
#    'xglm_oneshot_altex_2beam': ' John. Context: John is not a policeman, but Joseph and',
#    'xlm_zeroshot_1beam': ' John is a policeman.',
#    'xlm_zeroshot_2beam': ' John is a policeman, but Joseph and Thomas are.',
#    'xlm_oneshot_2beam': 'John. Context: John is not a policeman, but Joseph and'}},
#  '22': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Steve is not a singer, but Clark is. ',
#   'question': 'Who is a singer? ',
#   'answer': 'Clark.',
#   'prompt': 'Context: Steve is not a singer, but Clark is.  Question: Who is a singer?  Answer:',
#   'targets': {'N1': 'steve', 'P2': 'singer', 'P1': 'clark'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Clark. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Clark. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Steve is a singer.',
#    'xlm_zeroshot_2beam': ' Steve is not a singer, but Clark is.',
#    'xlm_oneshot_2beam': 'Clark. Context: Dennis is not a programmer, but Lisa is.'}},
#  '23': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Olivia and Emily are not architects, but Christopher and Charles are. ',
#   'question': 'Who are architects? ',
#   'answer': 'Christopher and Charles.',
#   'prompt': 'Context: Olivia and Emily are not architects, but Christopher and Charles are.  Question: Who are architects?  Answer:',
#   'targets': {'N1A': 'olivia',
#    'N1B': 'emily',
#    'P2': 'architects',
#    'P1A': 'christopher',
#    'P1B': 'charles'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Christopher. Context: Christopher and Charles are not architects.',
#    'xglm_oneshot_altex_2beam': ' Christopher and Charles. Context: Dennis is not a programmer, but Lisa',
#    'xlm_zeroshot_1beam': ' Christopher and Charles are architects.',
#    'xlm_zeroshot_2beam': ' Christopher and Charles are architects.',
#    'xlm_oneshot_2beam': 'Christopher and Charles. Context: Christopher and Charles. Context: Christopher'}},
#  '24': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Steve is not a farmer, but Mark and Andrew are. ',
#   'question': 'Who are farmers? ',
#   'answer': 'Mark and Andrew.',
#   'prompt': 'Context: Steve is not a farmer, but Mark and Andrew are.  Question: Who are farmers?  Answer:',
#   'targets': {'N1': 'steve', 'P2': 'farmer', 'P1A': 'mark', 'P1B': 'andrew'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Steve. Context: Mark. Context: Andrew. Context:',
#    'xglm_oneshot_altex_2beam': ' Steve. Context: Mark. Context: Andrew. Context:',
#    'xlm_zeroshot_1beam': ' Steve is a farmer. Mark is a farmer. Mark is a farmer.',
#    'xlm_zeroshot_2beam': ' Steve is a farmer. Mark is a farmer. Andrew is a farmer.',
#    'xlm_oneshot_2beam': 'Mark. Context: Andrew is not a farmer, but Mark and Andrew'}},
#  '25': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Rachel is not a policewoman, but Robert is. ',
#   'question': 'Who is a policeman? ',
#   'answer': 'Robert.',
#   'prompt': 'Context: Rachel is not a policewoman, but Robert is.  Question: Who is a policeman?  Answer:',
#   'targets': {'N1': 'rachel', 'P2': 'policewoman', 'P1': 'robert'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Robert. Context: Rachel. Context: Robert. Context:',
#    'xglm_oneshot_altex_2beam': ' Robert. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Rachel is a policewoman.',
#    'xlm_zeroshot_2beam': ' Rachel is a policewoman. Robert is a policeman.',
#    'xlm_oneshot_2beam': 'Robert. Context: Rachel is not a policewoman, but Robert is'}},
#  '26': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Robert is not a lawyer, but Paul and Bob are. ',
#   'question': 'Who are lawyers? ',
#   'answer': 'Paul and Bob.',
#   'prompt': 'Context: Robert is not a lawyer, but Paul and Bob are.  Question: Who are lawyers?  Answer:',
#   'targets': {'N1': 'robert', 'P2': 'lawyer', 'P1A': 'paul', 'P1B': 'bob'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Paul and Bob. Context: Dennis is not a lawyer, but Paul',
#    'xglm_oneshot_altex_2beam': ' Paul and Bob. Context: Paul and Bob. Context: Paul',
#    'xlm_zeroshot_1beam': ' Robert is a lawyer.',
#    'xlm_zeroshot_2beam': ' Robert is a lawyer, but Paul and Bob are lawyers.',
#    'xlm_oneshot_2beam': 'Paul and Bob. Context: Dennis is not a programmer, but Lisa'}},
#  '27': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not a lawyer, but Sophia and Charlotte are. ',
#   'question': 'Who are lawyers? ',
#   'answer': 'Sophia and Charlotte.',
#   'prompt': 'Context: Mary is not a lawyer, but Sophia and Charlotte are.  Question: Who are lawyers?  Answer:',
#   'targets': {'N1': 'mary',
#    'P2': 'lawyer',
#    'P1A': 'sophia',
#    'P1B': 'charlotte'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Mary. Context: Mary. Context: Mary. Context:',
#    'xglm_oneshot_altex_2beam': ' Mary. Context: Mary. Context: Mary. Context:',
#    'xlm_zeroshot_1beam': ' Mary is a lawyer.',
#    'xlm_zeroshot_2beam': ' Mary is not a lawyer, but Sophia and Charlotte are.',
#    'xlm_oneshot_2beam': 'Sophia. Context: Mary is not a lawyer, but Sophia and Charlotte'}},
#  '28': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not an actress, but Christopher and Charles are. ',
#   'question': 'Who are actors? ',
#   'answer': 'Christopher and Charles.',
#   'prompt': 'Context: Mary is not an actress, but Christopher and Charles are.  Question: Who are actors?  Answer:',
#   'targets': {'N1': 'mary',
#    'P2': 'actress',
#    'P1A': 'christopher',
#    'P1B': 'charles'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Christopher and Charles. Context: Dennis is not a programmer, but Lisa',
#    'xglm_oneshot_altex_2beam': ' Christopher and Charles. Context: Dennis is not a programmer, but Lisa',
#    'xlm_zeroshot_1beam': ' Mary is a.',
#    'xlm_zeroshot_2beam': ' Christopher and Charles are actors, but Mary is not an actress.',
#    'xlm_oneshot_2beam': 'Christopher and Charles. Context: Dennis is not a programmer, but Lisa'}},
#  '29': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Kirk is not a farmer, but Emma and Monica are. ',
#   'question': 'Who are farmers? ',
#   'answer': 'Emma and Monica.',
#   'prompt': 'Context: Kirk is not a farmer, but Emma and Monica are.  Question: Who are farmers?  Answer:',
#   'targets': {'N1': 'kirk', 'P2': 'farmer', 'P1A': 'emma', 'P1B': 'monica'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Kirk. Context: Kirk is not a farmer, but Emma and Monica',
#    'xglm_oneshot_altex_2beam': ' Kirk. Context: Kirk is not a farmer, but Emma and Monica',
#    'xlm_zeroshot_1beam': ' Kirk is a farmer.',
#    'xlm_zeroshot_2beam': ' Kirk is a farmer.',
#    'xlm_oneshot_2beam': 'Kirk. Context: Kirk is not a farmer, but Emma and Monica'}},
#  '30': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Steve is not a scientist, but Alice and Harper are. ',
#   'question': 'Who are scientists? ',
#   'answer': 'Alice and Harper.',
#   'prompt': 'Context: Steve is not a scientist, but Alice and Harper are.  Question: Who are scientists?  Answer:',
#   'targets': {'N1': 'steve',
#    'P2': 'scientist',
#    'P1A': 'alice',
#    'P1B': 'harper'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Steve. Context: Alice. Context: Harper. Context:',
#    'xglm_oneshot_altex_2beam': ' Steve. Context: Alice and Harper. Question: Who is not a',
#    'xlm_zeroshot_1beam': ' Steve is a scientist.',
#    'xlm_zeroshot_2beam': ' Steve is not a scientist, but Alice and Harper are.',
#    'xlm_oneshot_2beam': 'Alice. Context: Steve is not a scientist, but Alice and Harper'}},
#  '31': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not a waitress, but John is. ',
#   'question': 'Who is a waiter? ',
#   'answer': 'John.',
#   'prompt': 'Context: Mary is not a waitress, but John is.  Question: Who is a waiter?  Answer:',
#   'targets': {'N1': 'mary', 'P2': 'waitress', 'P1': 'john'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' John. Context: Mary is a waitress, but John is',
#    'xglm_oneshot_altex_2beam': ' John. Context: Mary is not a waitress, but John',
#    'xlm_zeroshot_1beam': ' Mary is a waitress.',
#    'xlm_zeroshot_2beam': ' Mary is a waitress, but John is a waiter.',
#    'xlm_oneshot_2beam': 'John. Context: Mary is not a waitress, but John'}},
#  '32': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Rachel is not an engineer, but Alice and Harper are. ',
#   'question': 'Who are engineers? ',
#   'answer': 'Alice and Harper.',
#   'prompt': 'Context: Rachel is not an engineer, but Alice and Harper are.  Question: Who are engineers?  Answer:',
#   'targets': {'N1': 'rachel',
#    'P2': 'engineer',
#    'P1A': 'alice',
#    'P1B': 'harper'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Rachel. Context: Rachel. Context: Rachel. Context:',
#    'xglm_oneshot_altex_2beam': ' Rachel. Context: Rachel. Context: Rachel. Context:',
#    'xlm_zeroshot_1beam': ' Rachel is an engineer.',
#    'xlm_zeroshot_2beam': ' Rachel is an engineer, but Alice and Harper are engineers.',
#    'xlm_oneshot_2beam': 'Alice. Context: Rachel. Context: Alice. Context:'}},
#  '33': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lily is not a policewoman, but Steve is. ',
#   'question': 'Who is a policeman? ',
#   'answer': 'Steve.',
#   'prompt': 'Context: Lily is not a policewoman, but Steve is.  Question: Who is a policeman?  Answer:',
#   'targets': {'N1': 'lily', 'P2': 'policewoman', 'P1': 'steve'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Steve. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Steve. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Lily is a policewoman.',
#    'xlm_zeroshot_2beam': ' Lily is a policewoman, but Steve is a policeman.',
#    'xlm_oneshot_2beam': 'Steve. Context: Lisa is not a policewoman, but Steve is'}},
#  '34': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lola is not an actress, but Joseph and Thomas are. ',
#   'question': 'Who are actors? ',
#   'answer': 'Joseph and Thomas.',
#   'prompt': 'Context: Lola is not an actress, but Joseph and Thomas are.  Question: Who are actors?  Answer:',
#   'targets': {'N1': 'lola', 'P2': 'actress', 'P1A': 'joseph', 'P1B': 'thomas'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Joseph and Thomas. Context: Dennis is not a programmer, but Lisa',
#    'xglm_oneshot_altex_2beam': ' Dennis. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Lola is a.',
#    'xlm_zeroshot_2beam': ' Joseph and Thomas are actors. Question: Who are actors? Answer: Joseph',
#    'xlm_oneshot_2beam': 'Joseph and Thomas. Context: Joseph and Thomas. Context: Joseph'}},
#  '35': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Susan is not a lawyer, but Robert is. ',
#   'question': 'Who is a lawyer? ',
#   'answer': 'Robert.',
#   'prompt': 'Context: Susan is not a lawyer, but Robert is.  Question: Who is a lawyer?  Answer:',
#   'targets': {'N1': 'susan', 'P2': 'lawyer', 'P1': 'robert'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Robert. Context: Susan is not a lawyer, but Robert is.',
#    'xglm_oneshot_altex_2beam': ' Robert. Context: Susan is not a lawyer, but Robert is.',
#    'xlm_zeroshot_1beam': ' Susan is a lawyer.',
#    'xlm_zeroshot_2beam': ' Susan is not a lawyer, but Robert is.',
#    'xlm_oneshot_2beam': 'Robert. Context: Dennis is not a programmer, but Lisa is.'}},
#  '36': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Rachel is not a policewoman, but Lily is. ',
#   'question': 'Who is a policeman? ',
#   'answer': 'Lily.',
#   'prompt': 'Context: Rachel is not a policewoman, but Lily is.  Question: Who is a policeman?  Answer:',
#   'targets': {'N1': 'rachel', 'P2': 'policewoman', 'P1': 'lily'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Rachel. Context: Rachel. Context: Rachel. Context:',
#    'xglm_oneshot_altex_2beam': ' Rachel. Context: Lisa is not a policewoman, but Lily is',
#    'xlm_zeroshot_1beam': ' Rachel is a policewoman.',
#    'xlm_zeroshot_2beam': ' Rachel is a policewoman, and Lily is a policewoman.',
#    'xlm_oneshot_2beam': 'Lily. Context: Dennis is not a programmer, but Lisa is.'}},
#  '37': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Eleanor and Lillian are not lawyers, but Joseph and Thomas are. ',
#   'question': 'Who are lawyers? ',
#   'answer': 'Joseph and Thomas.',
#   'prompt': 'Context: Eleanor and Lillian are not lawyers, but Joseph and Thomas are.  Question: Who are lawyers?  Answer:',
#   'targets': {'N1A': 'eleanor',
#    'N1B': 'lillian',
#    'P2': 'lawyers',
#    'P1A': 'joseph',
#    'P1B': 'thomas'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Joseph. Context: Joseph. Context: Joseph. Context:',
#    'xglm_oneshot_altex_2beam': ' Joseph. Context: Joseph. Context: Joseph. Context:',
#    'xlm_zeroshot_1beam': ' Joseph and Thomas are lawyers.',
#    'xlm_zeroshot_2beam': ' Eleanor and Lillian are not lawyers, but Joseph and Thomas are.',
#    'xlm_oneshot_2beam': 'Joseph and Thomas. Context: Joseph and Thomas are not lawyers, but'}},
#  '38': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lily is not a teacher, but Ross and Joey are. ',
#   'question': 'Who are teachers? ',
#   'answer': 'Ross and Joey.',
#   'prompt': 'Context: Lily is not a teacher, but Ross and Joey are.  Question: Who are teachers?  Answer:',
#   'targets': {'N1': 'lily', 'P2': 'teacher', 'P1A': 'ross', 'P1B': 'joey'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Lily. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Ross and Joey. Context: Dennis is not a programmer, but',
#    'xlm_zeroshot_1beam': ' Lily is a teacher.',
#    'xlm_zeroshot_2beam': ' Lily is not a teacher, but Ross and Joey are.',
#    'xlm_oneshot_2beam': 'Ross and Joey.'}},
#  '39': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lola is not a scientist, but Clark is. ',
#   'question': 'Who is a scientist? ',
#   'answer': 'Clark.',
#   'prompt': 'Context: Lola is not a scientist, but Clark is.  Question: Who is a scientist?  Answer:',
#   'targets': {'N1': 'lola', 'P2': 'scientist', 'P1': 'clark'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Clark. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Clark. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Clark is a scientist.',
#    'xlm_zeroshot_2beam': ' A scientist is a person who is interested in science. A scientist is a',
#    'xlm_oneshot_2beam': 'Clark. Context: Dennis is not a programmer, but Lisa is.'}},
#  '40': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Susan is not a doctor, but Kirk is. ',
#   'question': 'Who is a doctor? ',
#   'answer': 'Kirk.',
#   'prompt': 'Context: Susan is not a doctor, but Kirk is.  Question: Who is a doctor?  Answer:',
#   'targets': {'N1': 'susan', 'P2': 'doctor', 'P1': 'kirk'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Kirk. Context: Dennis is not a programmer, but Lisa is.',
#    'xglm_oneshot_altex_2beam': ' Kirk. Context: Dennis is not a programmer, but Lisa is.',
#    'xlm_zeroshot_1beam': ' Susan is a doctor.',
#    'xlm_zeroshot_2beam': ' Susan is not a doctor, but Kirk is.',
#    'xlm_oneshot_2beam': 'Kirk. Context: Dennis is not a programmer, but Lisa is.'}},
#  '41': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not a farmer, but Steve is. ',
#   'question': 'Who is a farmer? ',
#   'answer': 'Steve.',
#   'prompt': 'Context: Mary is not a farmer, but Steve is.  Question: Who is a farmer?  Answer:',
#   'targets': {'N1': 'mary', 'P2': 'farmer', 'P1': 'steve'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Steve. Context: Mary. Context: Steve. Context:',
#    'xglm_oneshot_altex_2beam': ' Steve. Context: Mary is not a farmer, but Steve is.',
#    'xlm_zeroshot_1beam': ' Mary is a farmer.',
#    'xlm_zeroshot_2beam': ' Mary is a farmer.',
#    'xlm_oneshot_2beam': 'Steve. Context: Mary is not a farmer, but Steve is.'}},
#  '42': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Steve is not an architect, but Ross and Joey are. ',
#   'question': 'Who are architects? ',
#   'answer': 'Ross and Joey.',
#   'prompt': 'Context: Steve is not an architect, but Ross and Joey are.  Question: Who are architects?  Answer:',
#   'targets': {'N1': 'steve', 'P2': 'architect', 'P1A': 'ross', 'P1B': 'joey'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Steve. Context: Steve. Context: Steve. Context:',
#    'xglm_oneshot_altex_2beam': ' Steve. Context: Steve. Context: Steve. Context:',
#    'xlm_zeroshot_1beam': ' Steve is an architect.',
#    'xlm_zeroshot_2beam': ' Steve is an architect, but Ross and Joey are architects.',
#    'xlm_oneshot_2beam': 'Ross and Joey. Context: Steve is not an architect, but'}},
#  '43': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not a scientist, but Ross and Joey are. ',
#   'question': 'Who are scientists? ',
#   'answer': 'Ross and Joey.',
#   'prompt': 'Context: Mary is not a scientist, but Ross and Joey are.  Question: Who are scientists?  Answer:',
#   'targets': {'N1': 'mary', 'P2': 'scientist', 'P1A': 'ross', 'P1B': 'joey'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Mary. Context: Mary. Context: Ross and Joey.',
#    'xglm_oneshot_altex_2beam': ' Ross and Joey. Context: Dennis is not a programmer, but',
#    'xlm_zeroshot_1beam': ' Mary is a scientist.',
#    'xlm_zeroshot_2beam': ' Ross and Joey are scientists.',
#    'xlm_oneshot_2beam': 'Ross and Joey.'}},
#  '44': {'task': 'negation1',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is not a singer, but Ross and Joey are. ',
#   'question': 'Who are singers? ',
#   'answer': 'Ross and Joey.',
#   'prompt': 'Context: Mary is not a singer, but Ross and Joey are.  Question: Who are singers?  Answer:',
#   'targets': {'N1': 'mary', 'P2': 'singer', 'P1A': 'ross', 'P1B': 'joey'},
#   'example_prompt': 'Context:  Dennis is not a programmer, but Lisa is. Question: Who is a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is not a programmer, but Lisa is. Question: Who is not a programmer? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Ross and Joey. Context: Dennis is not a programmer, but',
# ...
#  '986': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Sophia and Charlotte are accountants, Christopher and Charles are architects. ',
#   'question': 'Who are not accountants? ',
#   'answer': 'Christopher and Charles.',
#   'prompt': 'Context: Sophia and Charlotte are accountants, Christopher and Charles are architects.  Question: Who are not accountants?  Answer:',
#   'targets': {'N1A': 'sophia',
#    'N1B': 'charlotte',
#    'N2': 'accountants',
#    'P1A': 'christopher',
#    'P1B': 'charles',
#    'P2': 'architects'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Christopher. Context: Charles. Context: Charles. Context:',
#    'xglm_oneshot_altex_2beam': ' Christopher. Context: Charles. Context: Charles. Context:',
#    'xlm_zeroshot_1beam': ' They are not accountants.',
#    'xlm_zeroshot_2beam': ' They are not architects. Question: Who are not accountants? Answer',
#    'xlm_oneshot_2beam': 'Charles. Context: Dennis is a programmer, Lisa is a therapist.'}},
#  '987': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Steve is an actor, Emma and Monica are cooks. ',
#   'question': 'Who are not actors? ',
#   'answer': 'Emma and Monica.',
#   'prompt': 'Context: Steve is an actor, Emma and Monica are cooks.  Question: Who are not actors?  Answer:',
#   'targets': {'N1': 'steve',
#    'N2': 'actor',
#    'P1A': 'emma',
#    'P1B': 'monica',
#    'P2': 'cooks'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Emma. Context: Steve is a musician. Question: Who are not',
#    'xglm_oneshot_altex_2beam': ' Emma. Context: Monica is a singer. Question: Who are not',
#    'xlm_zeroshot_1beam': ' Emma is a singer, Monica is a model, and Steve is a musician',
#    'xlm_zeroshot_2beam': ' Steve is an actor, Emma and Monica are cooks.',
#    'xlm_oneshot_2beam': 'Emma. Context: Monica is a singer. Question: Who are not'}},
#  '988': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Robert is an actor, Emma and Monica are lawyers. ',
#   'question': 'Who are not actors? ',
#   'answer': 'Emma and Monica.',
#   'prompt': 'Context: Robert is an actor, Emma and Monica are lawyers.  Question: Who are not actors?  Answer:',
#   'targets': {'N1': 'robert',
#    'N2': 'actor',
#    'P1A': 'emma',
#    'P1B': 'monica',
#    'P2': 'lawyers'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Monica. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xglm_oneshot_altex_2beam': ' Monica. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xlm_zeroshot_1beam': ' Robert is an actor, Emma and Monica are lawyers.',
#    'xlm_zeroshot_2beam': ' Robert is an actor, Emma and Monica are lawyers.',
#    'xlm_oneshot_2beam': 'Monica. Context: Dennis is a programmer, Lisa is a therapist.'}},
#  '989': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Alice and Harper are engineers, Ross and Joey are teachers. ',
#   'question': 'Who are not engineers? ',
#   'answer': 'Ross and Joey.',
#   'prompt': 'Context: Alice and Harper are engineers, Ross and Joey are teachers.  Question: Who are not engineers?  Answer:',
#   'targets': {'N1A': 'alice',
#    'N1B': 'harper',
#    'N2': 'engineers',
#    'P1A': 'ross',
#    'P1B': 'joey',
#    'P2': 'teachers'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Ross. Context: Alice and Harper are engineers. Question: Who are',
#    'xglm_oneshot_altex_2beam': ' Ross and Joey. Context: Dennis is a programmer, Lisa is',
#    'xlm_zeroshot_1beam': ' They are engineers.',
#    'xlm_zeroshot_2beam': ' They are engineers, Ross and Joey are teachers, and Alice and Harper',
#    'xlm_oneshot_2beam': 'Ross and Joey. Context: Dennis is a programmer, Lisa is'}},
#  '990': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Kirk is a teacher, James is a policeman. ',
#   'question': 'Who is not a teacher? ',
#   'answer': 'James.',
#   'prompt': 'Context: Kirk is a teacher, James is a policeman.  Question: Who is not a teacher?  Answer:',
#   'targets': {'N1': 'kirk', 'N2': 'teacher', 'P1': 'james', 'P2': 'policeman'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' James. Context: Kirk is a policeman. Question: Who is',
#    'xglm_oneshot_altex_2beam': ' James. Context: Kirk is a teacher, James is a policeman',
#    'xlm_zeroshot_1beam': ' James is a policeman.',
#    'xlm_zeroshot_2beam': ' James is a policeman.',
#    'xlm_oneshot_2beam': 'James. Context: Kirk is a teacher, James is a policeman'}},
#  '991': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Robert is a teacher, Sophia and Charlotte are policewomen. ',
#   'question': 'Who are not teachers? ',
#   'answer': 'Sophia and Charlotte.',
#   'prompt': 'Context: Robert is a teacher, Sophia and Charlotte are policewomen.  Question: Who are not teachers?  Answer:',
#   'targets': {'N1': 'robert',
#    'N2': 'teacher',
#    'P1A': 'sophia',
#    'P1B': 'charlotte',
#    'P2': 'policewomen'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Robert. Context: Robert is a teacher. Question: Who are not',
#    'xglm_oneshot_altex_2beam': ' Robert. Context: Dennis is a teacher, Sophia and Charlotte are police',
#    'xlm_zeroshot_1beam': ' Robert is a teacher, Sophia and Charlotte are policewomen.',
#    'xlm_zeroshot_2beam': ' Robert is a teacher, Sophia and Charlotte are policewomen.',
#    'xlm_oneshot_2beam': 'Sophia and Charlotte. Context: Dennis is a programmer, Lisa is a'}},
#  '992': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Susan is a scientist, Audrey is an accountant. ',
#   'question': 'Who is not a scientist? ',
#   'answer': 'Audrey.',
#   'prompt': 'Context: Susan is a scientist, Audrey is an accountant.  Question: Who is not a scientist?  Answer:',
#   'targets': {'N1': 'susan',
#    'N2': 'scientist',
#    'P1': 'audrey',
#    'P2': 'accountant'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Susan. Context: Susan is a scientist. Question: Who is not',
#    'xglm_oneshot_altex_2beam': ' Susan. Context: Susan is a scientist. Question: Who is not',
#    'xlm_zeroshot_1beam': ' Susan is a scientist.',
#    'xlm_zeroshot_2beam': ' Susan is a scientist, Audrey is an accountant.',
#    'xlm_oneshot_2beam': 'Audrey. Context: Susan is a scientist, Audrey is an'}},
#  '993': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Audrey is a policewoman, Mark and Andrew are lawyers. ',
#   'question': 'Who are not policemen? ',
#   'answer': 'Mark and Andrew.',
#   'prompt': 'Context: Audrey is a policewoman, Mark and Andrew are lawyers.  Question: Who are not policemen?  Answer:',
#   'targets': {'N1': 'audrey',
#    'N2': 'policewoman',
#    'P1A': 'mark',
#    'P1B': 'andrew',
#    'P2': 'lawyers'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Mark. Context: Mark. Context: Mark. Context:',
#    'xglm_oneshot_altex_2beam': ' Mark. Context: Mark. Context: Mark. Context:',
#    'xlm_zeroshot_1beam': ' Mark is a policeman. Mark is a lawyer. Mark is a lawyer',
#    'xlm_zeroshot_2beam': ' Mark is a policeman. Mark is a lawyer. Mark is a lawyer',
#    'xlm_oneshot_2beam': 'Mark. Context: Mark and Andrew. Question: Who is not a'}},
#  '994': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is a singer, Lola is a doctor. ',
#   'question': 'Who is not a singer? ',
#   'answer': 'Lola.',
#   'prompt': 'Context: Mary is a singer, Lola is a doctor.  Question: Who is not a singer?  Answer:',
#   'targets': {'N1': 'mary', 'N2': 'singer', 'P1': 'lola', 'P2': 'doctor'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Lola. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xglm_oneshot_altex_2beam': ' Lola. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xlm_zeroshot_1beam': ' Mary is a singer.',
#    'xlm_zeroshot_2beam': ' Mary is a singer.',
#    'xlm_oneshot_2beam': 'Lola. Context: Dennis is a programmer, Lisa is a therapist.'}},
#  '995': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Steve is a singer, Mark and Andrew are architects. ',
#   'question': 'Who are not singers? ',
#   'answer': 'Mark and Andrew.',
#   'prompt': 'Context: Steve is a singer, Mark and Andrew are architects.  Question: Who are not singers?  Answer:',
#   'targets': {'N1': 'steve',
#    'N2': 'singer',
#    'P1A': 'mark',
#    'P1B': 'andrew',
#    'P2': 'architects'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Mark. Context: Mark. Context: Mark. Context:',
#    'xglm_oneshot_altex_2beam': ' Mark. Context: Mark. Context: Mark. Context:',
#    'xlm_zeroshot_1beam': ' Steve is a singer, Mark and Andrew are architects.',
#    'xlm_zeroshot_2beam': ' Steve is a singer, Mark and Andrew are architects.',
#    'xlm_oneshot_2beam': 'Mark. Context: Mark. Context: Mark. Context:'}},
#  '996': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Lily is a waitress, Mark and Andrew are policemen. ',
#   'question': 'Who are not waiters? ',
#   'answer': 'Mark and Andrew.',
#   'prompt': 'Context: Lily is a waitress, Mark and Andrew are policemen.  Question: Who are not waiters?  Answer:',
#   'targets': {'N1': 'lily',
#    'N2': 'waitress',
#    'P1A': 'mark',
#    'P1B': 'andrew',
#    'P2': 'policemen'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Mark. Context: Mark. Context: Mark. Context:',
#    'xglm_oneshot_altex_2beam': ' Mark. Context: Mark. Context: Mark. Context:',
#    'xlm_zeroshot_1beam': ' Mark is a waitress. Question: What is the difference between a',
#    'xlm_zeroshot_2beam': ' Mark is a waitress, Andrew is a policeman.',
#    'xlm_oneshot_2beam': 'Mark. Context: Mark. Context: Mark. Context:'}},
#  '997': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Susan is a teacher, Sophia and Charlotte are managers. ',
#   'question': 'Who are not teachers? ',
#   'answer': 'Sophia and Charlotte.',
#   'prompt': 'Context: Susan is a teacher, Sophia and Charlotte are managers.  Question: Who are not teachers?  Answer:',
#   'targets': {'N1': 'susan',
#    'N2': 'teacher',
#    'P1A': 'sophia',
#    'P1B': 'charlotte',
#    'P2': 'managers'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Susan. Context: Susan. Context: Susan. Context:',
#    'xglm_oneshot_altex_2beam': ' Susan. Context: Susan. Context: Susan. Context:',
#    'xlm_zeroshot_1beam': ' Susan is a teacher, Sophia and Charlotte are managers.',
#    'xlm_zeroshot_2beam': ' Susan is a teacher, Sophia and Charlotte are managers.',
#    'xlm_oneshot_2beam': 'Sophia. Context: Susan. Context: Sophia. Context:'}},
#  '998': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Audrey is a singer, Lily is a manager. ',
#   'question': 'Who is not a singer? ',
#   'answer': 'Lily.',
#   'prompt': 'Context: Audrey is a singer, Lily is a manager.  Question: Who is not a singer?  Answer:',
#   'targets': {'N1': 'audrey', 'N2': 'singer', 'P1': 'lily', 'P2': 'manager'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Lily. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xglm_oneshot_altex_2beam': ' Lily. Context: Dennis is a programmer, Lisa is a therapist.',
#    'xlm_zeroshot_1beam': ' Audrey is a singer.',
#    'xlm_zeroshot_2beam': ' Audrey is a singer, Lily is a manager.',
#    'xlm_oneshot_2beam': 'Lily. Context: Dennis is a programmer, Lisa is a therapist.'}},
#  '999': {'task': 'negation2',
#   'lang': 'en',
#   'prefix': 'Please answer the question in English.',
#   'context': 'Mary is a writer, Audrey is a doctor. ',
#   'question': 'Who is not a writer? ',
#   'answer': 'Audrey.',
#   'prompt': 'Context: Mary is a writer, Audrey is a doctor.  Question: Who is not a writer?  Answer:',
#   'targets': {'N1': 'mary', 'N2': 'writer', 'P1': 'audrey', 'P2': 'doctor'},
#   'example_prompt': 'Context:  Dennis is a programmer, Lisa is a therapist. Question: Who is not a programmer? Answer: Lisa.',
#   'altered_example_prompt': 'Context: Dennis is a programmer, Lisa is a therapist. Question: Who is not a therapist? Answer: Dennis.',
#   'response': {'xglm_oneshot_altex_1beam': ' Audrey. Context: Mary is a writer. Question: Who is',
#    'xglm_oneshot_altex_2beam': ' Audrey. Context: Dennis is a programmer, Lisa is a therapist',
#    'xlm_zeroshot_1beam': ' Mary is a writer.',
#    'xlm_zeroshot_2beam': ' Audrey is a doctor, Mary is a writer, Audrey is a',
#    'xlm_oneshot_2beam': 'Audrey. Context: Mary is a writer, Audrey is a'}},
#  ...}

# %%
# json.dump(data, open('/home/norrman/GitHub/multi-morph-checklist/M2C_responses_fixed.json', 'w'), indent=4)

# %%
data = json.load(open('/home/norrman/GitHub/multi-morph-checklist/M2C_responses_fixed.json'))
data["20000"]
# Out:
# {'task': 'numerals2',
#  'lang': 'ja_form',
#  'prefix': '日本語でお答えください。',
#  'context': 'テーブルの上に八個のイチゴと十個のカキがございます。富美子はイチゴを二個召し上がりました。',
#  'question': 'テーブルの上にイチゴはいくつございますか。',
#  'answer': '六個ございます。',
#  'prompt': '文脈: テーブルの上に八個のイチゴと十個のカキがございます。富美子はイチゴを二個召し上がりました。 質問: テーブルの上にイチゴはいくつございますか。 回答:',
#  'targets': {'P3': 'テーブルの上',
#   'N1A': '八個',
#   'P2': 'イチゴ',
#   'N1B': '十個',
#   'N2': 'カキ',
#   'N1C': '二個',
#   'P1': '六個'},
#  'example_prompt': '文脈:  テーブルの上に八個のいちじくと十個のさくらんぼがございます。昭夫はいちじくを二個召し上がりました。質問: テーブルの上にいちじくはいくつございますか。回答: 六個ございます。',
#  'altered_example_prompt': '文脈: テーブルの上に八個のいちじくと十個のさくらんぼがございます。昭夫はいちじくを二個召し上がりました。質問: テーブルの上にいちじくはいくつございますか。回答: 六個ございます。',
#  'response': {'xglm_oneshot_altex_1beam': '答: 六個ございます。 文脈: テーブルの上に八',
#   'xglm_oneshot_altex_2beam': '答: 六個ございます。 文脈: テーブルの上に八',
#   'xlm_zeroshot_1beam': '答: イチゴは、三個、カキは、二個',
#   'xlm_zeroshot_2beam': '答: イチゴは三個、カキは二個です。',
#   'xlm_oneshot_2beam': ': 六個ございます。 文脈: テーブルの上に八'}}
